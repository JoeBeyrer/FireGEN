# %%
from utils import *
from models import *
from loss import *
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import colors
from datetime import datetime

# %%
train_path = '../next_day_fires/next_day_wildfire_spread_train*'
val_path = '../next_day_fires/next_day_wildfire_spread_eval*'
test_path = '../next_day_fires/next_day_wildfire_spread_test*'
features = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask', 'FireMask']

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Training Data

# %%
train_dataset = get_dataset(
      train_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

train_inputs, train_labels = next(iter(train_dataset))

print(train_inputs.shape)
print(train_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
titles = [
  'Elevation',
  'Wind\ndirection',
  'Wind\nvelocity',
  'Min\ntemp',
  'Max\ntemp',
  'Humidity',
  'Precip',
  'Drought',
  'Vegetation',
  'Population\ndensity',
  'Energy\nrelease\ncomponent',
  'Previous\nfire\nmask',
  'Fire\nmask'
]

n_rows = 5
n_features = train_inputs.shape[3] 
CMAP = colors.ListedColormap(['black', 'silver', 'orangered'])
BOUNDS = [-1, -0.1, 0.001, 1]
NORM = colors.BoundaryNorm(BOUNDS, CMAP.N)
keys = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask']

# %%
# fig = plt.figure(figsize=(20,8))

# for i in range(n_rows):
#   for j in range(n_features + 1):
#     plt.subplot(n_rows, n_features + 1, i * (n_features + 1) + j + 1)
#     if i == 0:
#       plt.title(titles[j], fontsize=15)
#     if j < n_features - 1:
#       plt.imshow(train_inputs[i, j, :, :], cmap='viridis')
#     if j == n_features - 1:
#       plt.imshow(train_inputs[i, -1, :, :], cmap=CMAP, norm=NORM)
#     if j == n_features:
#       plt.imshow(train_labels[i, 0, :, :], cmap=CMAP, norm=NORM) 
#     plt.axis('off')
# plt.tight_layout()

# %% [markdown]
# ## Vlidation Data

# %%
val_dataset = get_dataset(
      val_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

val_inputs, val_labels = next(iter(val_dataset))

print(val_inputs.shape)
print(val_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %% [markdown]
# ## Test Data

# %%
test_dataset = get_dataset(
      test_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

test_inputs, test_labels = next(iter(val_dataset))

print(test_inputs.shape)
print(test_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
# Build DataLoader
train_loader = DataLoader(train_dataset, batch_size=None, num_workers=0, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=None, num_workers=0, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=None, num_workers=0, pin_memory=True)

# %% [markdown]
# # Model Initialization

# %%
folder_path = './gen_models'
gen_input_channels = 12
disc_input_channels = 13
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Hyperparameters

# %%
#  Hyperparameters
kernel_size = 4 # DO NOT CHANGE
stride = 2 # DO NOT CHANGE
padding = 1 # DO NOT CHANGE
dropout = 0.5

gen_lr = 1e-4
disc_lr = 1e-4

alpha = 1
lambd = 2
pos_weight = 30
bce_weight = 0.5

num_epochs = 1000
patience = 100

# %% [markdown]
# ### Model Initialization

# %%
generator = Generator(gen_input_channels, kernel_size, stride, padding, dropout)
discriminator = Discriminator(disc_input_channels, kernel_size, stride, padding)

generator.apply(init_weights)
discriminator.apply(init_weights)

generator.to(device)
discriminator.to(device)
# Out:
# Discriminator(
#   (e1): Conv2d(13, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (lr1): LeakyReLU(negative_slope=0.2)
#   (e2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr2): LeakyReLU(negative_slope=0.2)
#   (e3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr3): LeakyReLU(negative_slope=0.2)
#   (output): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# # Model Training

# %%
gen_best_val_loss = float('inf')
epochs_no_improve = 0
gen_best_model_state = None
bgen_est_model_filename = None

# Optimizers and loss functions
gen_optimizer = torch.optim.Adam(generator.parameters(), lr=gen_lr, betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(discriminator.parameters(), lr=disc_lr, betas=(0.5, 0.999))
gen_criterion = GenLoss(alpha=alpha, lambd=lambd, pos_weight=torch.tensor([pos_weight]).to(device), bce_weight=bce_weight)
disc_criterion = DiscLoss()
torch.autograd.set_detect_anomaly(True)
# Train over the entire dataset every epoch

generator.load_state_dict(torch.load("./gen_models/best_model_0.8274214518697638_20250427_160049.pth", map_location=device, weights_only=True))

for epoch in range(num_epochs):
    if epoch == 50:
        gen_best_val_loss = float('inf')
        gen_criterion.alpha = 0.5
        for p in discriminator.parameters():
            p.requires_grad = True
    elif epoch == 0:
        gen_criterion.alpha = 0
        for p in discriminator.parameters():
            p.requires_grad = False
            
    generator.train()
    discriminator.train()

    gen_total_loss = 0
    disc_total_loss = 0

    # Train in batches 
    for batch in train_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)
        # Update Discriminator
        disc_optimizer.zero_grad()

        # Generate fake images
        with torch.no_grad():
            generated = generator(images)
        generated_detached = generated.detach()

        # Discriminator loss
        real_pred = discriminator(target, images)
        fake_pred = discriminator(generated_detached, images)
        disc_loss = disc_criterion(real_pred, fake_pred)

        if epoch > 49:
            disc_loss.backward()
            disc_optimizer.step()

        # Update generator
        gen_optimizer.zero_grad()

        # Re-forward generator
        generated = generator(images)
        gen_pred = discriminator(generated, images)
        gen_loss = gen_criterion(
            gen_logits=generated, 
            disc_pred=gen_pred, 
            target_mask=target
        )
        #gen_loss = gen_criterion(gen_pred, generated, target)

        gen_loss.backward()
        gen_optimizer.step()

        # Add loss to totals
        gen_total_loss = gen_total_loss + gen_loss.item()
        disc_total_loss = disc_total_loss + disc_loss.item()

    # Average the loss over all batches
    gen_avg_loss = gen_total_loss / len(train_loader)
    disc_avg_loss = disc_total_loss / len(train_loader)


    # Now, validate the model
    generator.eval()
    discriminator.eval()
    gen_val_loss = 0
    disc_val_loss = 0

    # Gradients are not used as validation is used to find the best model without further optimization
    with torch.no_grad():
        # Validate in batches
        for batch in val_loader:
            images, target = batch
            images = images.to(device)
            target = target.to(device)
            
            # Make predictions on the validation images
            generated = generator(images)
            gen_pred = discriminator(generated, images)
            real_pred = discriminator(target, images)

            # Calculate the loss
            #gen_loss = gen_criterion(gen_pred, generated, target)
            gen_loss = gen_criterion(
                gen_logits=generated, 
                disc_pred=gen_pred, 
                target_mask=target
            )
            disc_loss = disc_criterion(real_pred, gen_pred)
            gen_val_loss = gen_val_loss + gen_loss.item()
            disc_val_loss = disc_val_loss + disc_loss.item()


    
    # Average the validation loss over all batches
    gen_avg_val_loss = gen_val_loss / len(val_loader)
    disc_avg_val_loss = disc_val_loss / len(val_loader)
    
    
    print(f"Epoch {epoch + 1}/{num_epochs}\
          \n   - Generator Train Loss: {gen_avg_loss:.4f} - Generator Validation Loss: {gen_avg_val_loss:.4f}\
          \n   - Discriminator Train Loss: {disc_avg_loss:.4f} - Discriminator Validation Loss: {disc_avg_val_loss:.4f}")

    # Best model saving & early stopping
    if gen_avg_val_loss < gen_best_val_loss:
        gen_best_val_loss = gen_avg_val_loss
        epochs_no_improve = 0
        gen_best_model_state = generator.state_dict() 
        gen_best_model_filename = f"{folder_path}/best_model_{str(gen_best_val_loss)}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pth"
        print("Validation loss improved. Best model updated.")
    else:
        epochs_no_improve += 1
        print(f"No improvement for {epochs_no_improve} epoch(s).")
    
    if epochs_no_improve >= patience:
        print("Early stopping triggered!")
        break
# Out:
# Epoch 1/1000
#    - Generator Train Loss: 2.6854 - Generator Validation Loss: 2.6421
#    - Discriminator Train Loss: 1.5029 - Discriminator Validation Loss: 1.4492
# Validation loss improved. Best model updated.
# Epoch 2/1000
#    - Generator Train Loss: 2.6858 - Generator Validation Loss: 2.6691
#    - Discriminator Train Loss: 1.5048 - Discriminator Validation Loss: 1.4710
# No improvement for 1 epoch(s).
# Epoch 3/1000
#    - Generator Train Loss: 2.6787 - Generator Validation Loss: 2.6245
#    - Discriminator Train Loss: 1.5039 - Discriminator Validation Loss: 1.4589
# Validation loss improved. Best model updated.
# Epoch 4/1000
#    - Generator Train Loss: 2.6771 - Generator Validation Loss: 2.6469
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4672
# No improvement for 1 epoch(s).
# Epoch 5/1000
#    - Generator Train Loss: 2.6832 - Generator Validation Loss: 2.6992
#    - Discriminator Train Loss: 1.5033 - Discriminator Validation Loss: 1.4795
# No improvement for 2 epoch(s).
# Epoch 6/1000
#    - Generator Train Loss: 2.6736 - Generator Validation Loss: 2.5648
#    - Discriminator Train Loss: 1.5027 - Discriminator Validation Loss: 1.4357
# Validation loss improved. Best model updated.
# Epoch 7/1000
#    - Generator Train Loss: 2.6753 - Generator Validation Loss: 2.7411
#    - Discriminator Train Loss: 1.5018 - Discriminator Validation Loss: 1.4942
# No improvement for 1 epoch(s).
# Epoch 8/1000
#    - Generator Train Loss: 2.6692 - Generator Validation Loss: 2.7291
#    - Discriminator Train Loss: 1.5024 - Discriminator Validation Loss: 1.4955
# No improvement for 2 epoch(s).
# Epoch 9/1000
#    - Generator Train Loss: 2.6710 - Generator Validation Loss: 2.7082
#    - Discriminator Train Loss: 1.5021 - Discriminator Validation Loss: 1.4899
# No improvement for 3 epoch(s).
# Epoch 10/1000
#    - Generator Train Loss: 2.6797 - Generator Validation Loss: 2.5955
#    - Discriminator Train Loss: 1.5041 - Discriminator Validation Loss: 1.4395
# No improvement for 4 epoch(s).
# Epoch 11/1000
#    - Generator Train Loss: 2.6726 - Generator Validation Loss: 2.6439
#    - Discriminator Train Loss: 1.5017 - Discriminator Validation Loss: 1.4374
# No improvement for 5 epoch(s).
# Epoch 12/1000
#    - Generator Train Loss: 2.6813 - Generator Validation Loss: 2.7155
#    - Discriminator Train Loss: 1.5035 - Discriminator Validation Loss: 1.4906
# No improvement for 6 epoch(s).
# Epoch 13/1000
#    - Generator Train Loss: 2.6722 - Generator Validation Loss: 2.6461
#    - Discriminator Train Loss: 1.5025 - Discriminator Validation Loss: 1.4439
# No improvement for 7 epoch(s).
# Epoch 14/1000
#    - Generator Train Loss: 2.6699 - Generator Validation Loss: 2.7272
#    - Discriminator Train Loss: 1.5015 - Discriminator Validation Loss: 1.4908
# No improvement for 8 epoch(s).
# Epoch 15/1000
#    - Generator Train Loss: 2.6754 - Generator Validation Loss: 2.5184
#    - Discriminator Train Loss: 1.5033 - Discriminator Validation Loss: 1.4179
# Validation loss improved. Best model updated.
# Epoch 16/1000
#    - Generator Train Loss: 2.6834 - Generator Validation Loss: 2.7298
#    - Discriminator Train Loss: 1.5043 - Discriminator Validation Loss: 1.4955
# No improvement for 1 epoch(s).
# Epoch 17/1000
#    - Generator Train Loss: 2.6757 - Generator Validation Loss: 2.7226
#    - Discriminator Train Loss: 1.5036 - Discriminator Validation Loss: 1.4941
# No improvement for 2 epoch(s).
# Epoch 18/1000
#    - Generator Train Loss: 2.6724 - Generator Validation Loss: 2.6786
#    - Discriminator Train Loss: 1.5026 - Discriminator Validation Loss: 1.4779
# No improvement for 3 epoch(s).
# Epoch 19/1000
#    - Generator Train Loss: 2.6739 - Generator Validation Loss: 2.7214
#    - Discriminator Train Loss: 1.5027 - Discriminator Validation Loss: 1.4925
# No improvement for 4 epoch(s).
# Epoch 20/1000
#    - Generator Train Loss: 2.6814 - Generator Validation Loss: 2.7315
#    - Discriminator Train Loss: 1.5043 - Discriminator Validation Loss: 1.4984
# No improvement for 5 epoch(s).
# Epoch 21/1000
#    - Generator Train Loss: 2.6686 - Generator Validation Loss: 2.7402
#    - Discriminator Train Loss: 1.5017 - Discriminator Validation Loss: 1.4957
# No improvement for 6 epoch(s).
# Epoch 22/1000
#    - Generator Train Loss: 2.6725 - Generator Validation Loss: 2.7125
#    - Discriminator Train Loss: 1.5018 - Discriminator Validation Loss: 1.4861
# No improvement for 7 epoch(s).
# Epoch 23/1000
#    - Generator Train Loss: 2.6714 - Generator Validation Loss: 2.7147
#    - Discriminator Train Loss: 1.5022 - Discriminator Validation Loss: 1.4889
# No improvement for 8 epoch(s).
# Epoch 24/1000
#    - Generator Train Loss: 2.6755 - Generator Validation Loss: 2.6592
#    - Discriminator Train Loss: 1.5030 - Discriminator Validation Loss: 1.4749
# No improvement for 9 epoch(s).
# Epoch 25/1000
#    - Generator Train Loss: 2.6743 - Generator Validation Loss: 2.6558
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4669
# No improvement for 10 epoch(s).
# Epoch 26/1000
#    - Generator Train Loss: 2.6737 - Generator Validation Loss: 2.6297
#    - Discriminator Train Loss: 1.5018 - Discriminator Validation Loss: 1.4458
# No improvement for 11 epoch(s).
# Epoch 27/1000
#    - Generator Train Loss: 2.6708 - Generator Validation Loss: 2.6328
#    - Discriminator Train Loss: 1.5014 - Discriminator Validation Loss: 1.4427
# No improvement for 12 epoch(s).
# Epoch 28/1000
#    - Generator Train Loss: 2.6719 - Generator Validation Loss: 2.5975
#    - Discriminator Train Loss: 1.5018 - Discriminator Validation Loss: 1.4332
# No improvement for 13 epoch(s).
# Epoch 29/1000
#    - Generator Train Loss: 2.6766 - Generator Validation Loss: 2.6902
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4807
# No improvement for 14 epoch(s).
# Epoch 30/1000
#    - Generator Train Loss: 2.6738 - Generator Validation Loss: 2.6828
#    - Discriminator Train Loss: 1.5020 - Discriminator Validation Loss: 1.4757
# No improvement for 15 epoch(s).
# Epoch 31/1000
#    - Generator Train Loss: 2.6770 - Generator Validation Loss: 2.7421
#    - Discriminator Train Loss: 1.5032 - Discriminator Validation Loss: 1.4934
# No improvement for 16 epoch(s).
# Epoch 32/1000
#    - Generator Train Loss: 2.6782 - Generator Validation Loss: 2.7343
#    - Discriminator Train Loss: 1.5038 - Discriminator Validation Loss: 1.4948
# No improvement for 17 epoch(s).
# Epoch 33/1000
#    - Generator Train Loss: 2.6747 - Generator Validation Loss: 2.7419
#    - Discriminator Train Loss: 1.5030 - Discriminator Validation Loss: 1.4939
# No improvement for 18 epoch(s).
# Epoch 34/1000
#    - Generator Train Loss: 2.6709 - Generator Validation Loss: 2.6762
#    - Discriminator Train Loss: 1.5029 - Discriminator Validation Loss: 1.4742
# No improvement for 19 epoch(s).
# Epoch 35/1000
#    - Generator Train Loss: 2.6823 - Generator Validation Loss: 2.7329
#    - Discriminator Train Loss: 1.5039 - Discriminator Validation Loss: 1.4899
# No improvement for 20 epoch(s).
# Epoch 36/1000
#    - Generator Train Loss: 2.6741 - Generator Validation Loss: 2.5953
#    - Discriminator Train Loss: 1.5023 - Discriminator Validation Loss: 1.4412
# No improvement for 21 epoch(s).
# Epoch 37/1000
#    - Generator Train Loss: 2.6679 - Generator Validation Loss: 2.7447
#    - Discriminator Train Loss: 1.5022 - Discriminator Validation Loss: 1.4954
# No improvement for 22 epoch(s).
# Epoch 38/1000
#    - Generator Train Loss: 2.6767 - Generator Validation Loss: 2.7360
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4952
# No improvement for 23 epoch(s).
# Epoch 39/1000
#    - Generator Train Loss: 2.6696 - Generator Validation Loss: 2.6636
#    - Discriminator Train Loss: 1.5021 - Discriminator Validation Loss: 1.4698
# No improvement for 24 epoch(s).
# Epoch 40/1000
#    - Generator Train Loss: 2.6773 - Generator Validation Loss: 2.7342
#    - Discriminator Train Loss: 1.5032 - Discriminator Validation Loss: 1.4948
# No improvement for 25 epoch(s).
# Epoch 41/1000
#    - Generator Train Loss: 2.6717 - Generator Validation Loss: 2.6891
#    - Discriminator Train Loss: 1.5024 - Discriminator Validation Loss: 1.4835
# No improvement for 26 epoch(s).
# Epoch 42/1000
#    - Generator Train Loss: 2.6710 - Generator Validation Loss: 2.6826
#    - Discriminator Train Loss: 1.5032 - Discriminator Validation Loss: 1.4813
# No improvement for 27 epoch(s).
# Epoch 43/1000
#    - Generator Train Loss: 2.6718 - Generator Validation Loss: 2.6309
#    - Discriminator Train Loss: 1.5021 - Discriminator Validation Loss: 1.4449
# No improvement for 28 epoch(s).
# Epoch 44/1000
#    - Generator Train Loss: 2.6754 - Generator Validation Loss: 2.7134
#    - Discriminator Train Loss: 1.5031 - Discriminator Validation Loss: 1.4922
# No improvement for 29 epoch(s).
# Epoch 45/1000
#    - Generator Train Loss: 2.6768 - Generator Validation Loss: 2.7485
#    - Discriminator Train Loss: 1.5037 - Discriminator Validation Loss: 1.4950
# No improvement for 30 epoch(s).
# Epoch 46/1000
#    - Generator Train Loss: 2.6740 - Generator Validation Loss: 2.5104
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4189
# Validation loss improved. Best model updated.
# Epoch 47/1000
#    - Generator Train Loss: 2.6694 - Generator Validation Loss: 2.6280
#    - Discriminator Train Loss: 1.5019 - Discriminator Validation Loss: 1.4475
# No improvement for 1 epoch(s).
# Epoch 48/1000
#    - Generator Train Loss: 2.6731 - Generator Validation Loss: 2.6155
#    - Discriminator Train Loss: 1.5021 - Discriminator Validation Loss: 1.4507
# No improvement for 2 epoch(s).
# Epoch 49/1000
#    - Generator Train Loss: 2.6772 - Generator Validation Loss: 2.7221
#    - Discriminator Train Loss: 1.5041 - Discriminator Validation Loss: 1.4963
# No improvement for 3 epoch(s).
# Epoch 50/1000
#    - Generator Train Loss: 2.6747 - Generator Validation Loss: 2.6558
#    - Discriminator Train Loss: 1.5034 - Discriminator Validation Loss: 1.4701
# No improvement for 4 epoch(s).
# Epoch 51/1000
#    - Generator Train Loss: 2.1646 - Generator Validation Loss: 2.2440
#    - Discriminator Train Loss: 1.4024 - Discriminator Validation Loss: 1.3896
# Validation loss improved. Best model updated.
# Epoch 52/1000
#    - Generator Train Loss: 2.1562 - Generator Validation Loss: 2.2415
#    - Discriminator Train Loss: 1.3910 - Discriminator Validation Loss: 1.3877
# Validation loss improved. Best model updated.
# Epoch 53/1000
#    - Generator Train Loss: 2.1605 - Generator Validation Loss: 2.2352
#    - Discriminator Train Loss: 1.3903 - Discriminator Validation Loss: 1.3870
# Validation loss improved. Best model updated.
# Epoch 54/1000
#    - Generator Train Loss: 2.1545 - Generator Validation Loss: 2.2257
#    - Discriminator Train Loss: 1.3883 - Discriminator Validation Loss: 1.3868
# Validation loss improved. Best model updated.
# Epoch 55/1000
#    - Generator Train Loss: 2.1561 - Generator Validation Loss: 2.2287
#    - Discriminator Train Loss: 1.3887 - Discriminator Validation Loss: 1.3868
# No improvement for 1 epoch(s).
# Epoch 56/1000
#    - Generator Train Loss: 2.1563 - Generator Validation Loss: 2.2365
#    - Discriminator Train Loss: 1.3869 - Discriminator Validation Loss: 1.3866
# No improvement for 2 epoch(s).
# Epoch 57/1000
#    - Generator Train Loss: 2.1643 - Generator Validation Loss: 2.2326
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3866
# No improvement for 3 epoch(s).
# Epoch 58/1000
#    - Generator Train Loss: 2.1597 - Generator Validation Loss: 2.2414
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3866
# No improvement for 4 epoch(s).
# Epoch 59/1000
#    - Generator Train Loss: 2.1585 - Generator Validation Loss: 2.2258
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3865
# No improvement for 5 epoch(s).
# Epoch 60/1000
#    - Generator Train Loss: 2.1558 - Generator Validation Loss: 2.2401
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3865
# No improvement for 6 epoch(s).
# Epoch 61/1000
#    - Generator Train Loss: 2.1595 - Generator Validation Loss: 2.2235
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3865
# Validation loss improved. Best model updated.
# Epoch 62/1000
#    - Generator Train Loss: 2.1603 - Generator Validation Loss: 2.2423
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3868
# No improvement for 1 epoch(s).
# Epoch 63/1000
#    - Generator Train Loss: 2.1570 - Generator Validation Loss: 2.2336
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3864
# No improvement for 2 epoch(s).
# Epoch 64/1000
#    - Generator Train Loss: 2.1564 - Generator Validation Loss: 2.2565
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3891
# No improvement for 3 epoch(s).
# Epoch 65/1000
#    - Generator Train Loss: 2.1554 - Generator Validation Loss: 2.2286
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3865
# No improvement for 4 epoch(s).
# Epoch 66/1000
#    - Generator Train Loss: 2.1573 - Generator Validation Loss: 2.2538
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3868
# No improvement for 5 epoch(s).
# Epoch 67/1000
#    - Generator Train Loss: 2.1601 - Generator Validation Loss: 2.2459
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3865
# No improvement for 6 epoch(s).
# Epoch 68/1000
#    - Generator Train Loss: 2.1560 - Generator Validation Loss: 2.2423
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3865
# No improvement for 7 epoch(s).
# Epoch 69/1000
#    - Generator Train Loss: 2.1525 - Generator Validation Loss: 2.2166
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3867
# Validation loss improved. Best model updated.
# Epoch 70/1000
#    - Generator Train Loss: 2.1531 - Generator Validation Loss: 2.2329
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3869
# No improvement for 1 epoch(s).
# Epoch 71/1000
#    - Generator Train Loss: 2.1579 - Generator Validation Loss: 2.2299
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3865
# No improvement for 2 epoch(s).
# Epoch 72/1000
#    - Generator Train Loss: 2.1598 - Generator Validation Loss: 2.2348
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3864
# No improvement for 3 epoch(s).
# Epoch 73/1000
#    - Generator Train Loss: 2.1545 - Generator Validation Loss: 2.2281
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3876
# No improvement for 4 epoch(s).
# Epoch 74/1000
#    - Generator Train Loss: 2.1575 - Generator Validation Loss: 2.2308
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3864
# No improvement for 5 epoch(s).
# Epoch 75/1000
#    - Generator Train Loss: 2.1547 - Generator Validation Loss: 2.3151
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3896
# No improvement for 6 epoch(s).
# Epoch 76/1000
#    - Generator Train Loss: 2.1584 - Generator Validation Loss: 2.2374
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3861
# No improvement for 7 epoch(s).
# Epoch 77/1000
#    - Generator Train Loss: 2.1563 - Generator Validation Loss: 2.2270
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3860
# No improvement for 8 epoch(s).
# Epoch 78/1000
#    - Generator Train Loss: 2.1547 - Generator Validation Loss: 2.2670
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3872
# No improvement for 9 epoch(s).
# Epoch 79/1000
#    - Generator Train Loss: 2.1577 - Generator Validation Loss: 2.2861
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3886
# No improvement for 10 epoch(s).
# Epoch 80/1000
#    - Generator Train Loss: 2.1563 - Generator Validation Loss: 2.3266
#    - Discriminator Train Loss: 1.3864 - Discriminator Validation Loss: 1.3893
# No improvement for 11 epoch(s).
# Epoch 81/1000
#    - Generator Train Loss: 2.1566 - Generator Validation Loss: 2.2212
#    - Discriminator Train Loss: 1.3861 - Discriminator Validation Loss: 1.3870
# No improvement for 12 epoch(s).
# Epoch 82/1000
#    - Generator Train Loss: 2.1627 - Generator Validation Loss: 2.2223
#    - Discriminator Train Loss: 1.3860 - Discriminator Validation Loss: 1.3866
# No improvement for 13 epoch(s).
# Epoch 83/1000
#    - Generator Train Loss: 2.1664 - Generator Validation Loss: 2.3747
#    - Discriminator Train Loss: 1.3857 - Discriminator Validation Loss: 1.3928
# No improvement for 14 epoch(s).
# Epoch 84/1000
#    - Generator Train Loss: 2.1667 - Generator Validation Loss: 2.1892
#    - Discriminator Train Loss: 1.3852 - Discriminator Validation Loss: 1.3889
# Validation loss improved. Best model updated.
# Epoch 85/1000
#    - Generator Train Loss: 2.1741 - Generator Validation Loss: 2.4719
#    - Discriminator Train Loss: 1.3852 - Discriminator Validation Loss: 1.3982
# No improvement for 1 epoch(s).
# Epoch 86/1000
#    - Generator Train Loss: 2.1790 - Generator Validation Loss: 2.2494
#    - Discriminator Train Loss: 1.3848 - Discriminator Validation Loss: 1.3879
# No improvement for 2 epoch(s).
# Epoch 87/1000
#    - Generator Train Loss: 2.1766 - Generator Validation Loss: 2.3131
#    - Discriminator Train Loss: 1.3843 - Discriminator Validation Loss: 1.3891
# No improvement for 3 epoch(s).
# Epoch 88/1000
#    - Generator Train Loss: 2.1764 - Generator Validation Loss: 2.2042
#    - Discriminator Train Loss: 1.3831 - Discriminator Validation Loss: 1.3895
# No improvement for 4 epoch(s).
# Epoch 89/1000
#    - Generator Train Loss: 2.1790 - Generator Validation Loss: 2.2285
#    - Discriminator Train Loss: 1.3847 - Discriminator Validation Loss: 1.3875
# No improvement for 5 epoch(s).
# Epoch 90/1000
#    - Generator Train Loss: 2.1744 - Generator Validation Loss: 2.2806
#    - Discriminator Train Loss: 1.3841 - Discriminator Validation Loss: 1.3865
# No improvement for 6 epoch(s).
# Epoch 91/1000
#    - Generator Train Loss: 2.1877 - Generator Validation Loss: 2.2344
#    - Discriminator Train Loss: 1.3838 - Discriminator Validation Loss: 1.3867
# No improvement for 7 epoch(s).
# Epoch 92/1000
#    - Generator Train Loss: 2.1944 - Generator Validation Loss: 2.2328
#    - Discriminator Train Loss: 1.3820 - Discriminator Validation Loss: 1.3867
# No improvement for 8 epoch(s).
# Epoch 93/1000
#    - Generator Train Loss: 2.1888 - Generator Validation Loss: 2.1343
#    - Discriminator Train Loss: 1.3793 - Discriminator Validation Loss: 1.3923
# Validation loss improved. Best model updated.
# Epoch 94/1000
#    - Generator Train Loss: 2.2006 - Generator Validation Loss: 2.3751
#    - Discriminator Train Loss: 1.3767 - Discriminator Validation Loss: 1.3941
# No improvement for 1 epoch(s).
# Epoch 95/1000
#    - Generator Train Loss: 2.1999 - Generator Validation Loss: 2.3188
#    - Discriminator Train Loss: 1.3773 - Discriminator Validation Loss: 1.3909
# No improvement for 2 epoch(s).
# Epoch 96/1000
#    - Generator Train Loss: 2.2277 - Generator Validation Loss: 1.9523
#    - Discriminator Train Loss: 1.3685 - Discriminator Validation Loss: 1.4171
# Validation loss improved. Best model updated.
# Epoch 97/1000
#    - Generator Train Loss: 2.2080 - Generator Validation Loss: 2.0836
#    - Discriminator Train Loss: 1.3723 - Discriminator Validation Loss: 1.4051
# No improvement for 1 epoch(s).
# Epoch 98/1000
#    - Generator Train Loss: 2.2128 - Generator Validation Loss: 2.3654
#    - Discriminator Train Loss: 1.3740 - Discriminator Validation Loss: 1.3912
# No improvement for 2 epoch(s).
# Epoch 99/1000
#    - Generator Train Loss: 2.2196 - Generator Validation Loss: 2.2566
#    - Discriminator Train Loss: 1.3704 - Discriminator Validation Loss: 1.3880
# No improvement for 3 epoch(s).
# Epoch 100/1000
#    - Generator Train Loss: 2.2446 - Generator Validation Loss: 2.1477
#    - Discriminator Train Loss: 1.3592 - Discriminator Validation Loss: 1.3973
# No improvement for 4 epoch(s).
# Epoch 101/1000
#    - Generator Train Loss: 2.2153 - Generator Validation Loss: 2.3453
#    - Discriminator Train Loss: 1.3720 - Discriminator Validation Loss: 1.3939
# No improvement for 5 epoch(s).
# Epoch 102/1000
#    - Generator Train Loss: 2.2845 - Generator Validation Loss: 2.2605
#    - Discriminator Train Loss: 1.3521 - Discriminator Validation Loss: 1.3895
# No improvement for 6 epoch(s).
# Epoch 103/1000
#    - Generator Train Loss: 2.2117 - Generator Validation Loss: 2.2575
#    - Discriminator Train Loss: 1.3810 - Discriminator Validation Loss: 1.3868
# No improvement for 7 epoch(s).
# Epoch 104/1000
#    - Generator Train Loss: 2.2456 - Generator Validation Loss: 2.3148
#    - Discriminator Train Loss: 1.3648 - Discriminator Validation Loss: 1.3875
# No improvement for 8 epoch(s).
# Epoch 105/1000
#    - Generator Train Loss: 2.2542 - Generator Validation Loss: 2.2959
#    - Discriminator Train Loss: 1.3590 - Discriminator Validation Loss: 1.3981
# No improvement for 9 epoch(s).
# Epoch 106/1000
#    - Generator Train Loss: 2.3418 - Generator Validation Loss: 2.3455
#    - Discriminator Train Loss: 1.3347 - Discriminator Validation Loss: 1.3969
# No improvement for 10 epoch(s).
# Epoch 107/1000
#    - Generator Train Loss: 2.3462 - Generator Validation Loss: 2.2243
#    - Discriminator Train Loss: 1.3325 - Discriminator Validation Loss: 1.3869
# No improvement for 11 epoch(s).
# Epoch 108/1000
#    - Generator Train Loss: 2.2119 - Generator Validation Loss: 2.1972
#    - Discriminator Train Loss: 1.3832 - Discriminator Validation Loss: 1.3965
# No improvement for 12 epoch(s).
# Epoch 109/1000
#    - Generator Train Loss: 2.2006 - Generator Validation Loss: 2.2260
#    - Discriminator Train Loss: 1.3883 - Discriminator Validation Loss: 1.3923
# No improvement for 13 epoch(s).
# Epoch 110/1000
#    - Generator Train Loss: 2.3553 - Generator Validation Loss: 2.3312
#    - Discriminator Train Loss: 1.3273 - Discriminator Validation Loss: 1.3940
# No improvement for 14 epoch(s).
# Epoch 111/1000
#    - Generator Train Loss: 2.2145 - Generator Validation Loss: 2.2615
#    - Discriminator Train Loss: 1.3718 - Discriminator Validation Loss: 1.3858
# No improvement for 15 epoch(s).
# Epoch 112/1000
#    - Generator Train Loss: 2.3438 - Generator Validation Loss: 2.2715
#    - Discriminator Train Loss: 1.3441 - Discriminator Validation Loss: 1.3869
# No improvement for 16 epoch(s).
# Epoch 113/1000
#    - Generator Train Loss: 2.3373 - Generator Validation Loss: 2.8427
#    - Discriminator Train Loss: 1.3433 - Discriminator Validation Loss: 1.4725
# No improvement for 17 epoch(s).
# Epoch 114/1000
#    - Generator Train Loss: 2.3088 - Generator Validation Loss: 2.3359
#    - Discriminator Train Loss: 1.3448 - Discriminator Validation Loss: 1.3997
# No improvement for 18 epoch(s).
# Epoch 115/1000
#    - Generator Train Loss: 2.2870 - Generator Validation Loss: 2.2467
#    - Discriminator Train Loss: 1.3616 - Discriminator Validation Loss: 1.3860
# No improvement for 19 epoch(s).
# Epoch 116/1000
#    - Generator Train Loss: 2.1801 - Generator Validation Loss: 2.2891
#    - Discriminator Train Loss: 1.3814 - Discriminator Validation Loss: 1.3826
# No improvement for 20 epoch(s).
# Epoch 117/1000
#    - Generator Train Loss: 2.6518 - Generator Validation Loss: 2.4836
#    - Discriminator Train Loss: 1.2348 - Discriminator Validation Loss: 1.3748
# No improvement for 21 epoch(s).
# Epoch 118/1000
#    - Generator Train Loss: 2.5679 - Generator Validation Loss: 2.4439
#    - Discriminator Train Loss: 1.2673 - Discriminator Validation Loss: 1.4585
# No improvement for 22 epoch(s).
# Epoch 119/1000
#    - Generator Train Loss: 2.9590 - Generator Validation Loss: 2.2649
#    - Discriminator Train Loss: 1.1559 - Discriminator Validation Loss: 1.3916
# No improvement for 23 epoch(s).
# Epoch 120/1000
#    - Generator Train Loss: 3.0476 - Generator Validation Loss: 2.3732
#    - Discriminator Train Loss: 1.1194 - Discriminator Validation Loss: 1.3995
# No improvement for 24 epoch(s).
# Epoch 121/1000
#    - Generator Train Loss: 2.2411 - Generator Validation Loss: 2.2061
#    - Discriminator Train Loss: 1.3774 - Discriminator Validation Loss: 1.3864
# No improvement for 25 epoch(s).
# Epoch 122/1000
#    - Generator Train Loss: 2.2537 - Generator Validation Loss: 2.5376
#    - Discriminator Train Loss: 1.3548 - Discriminator Validation Loss: 1.4564
# No improvement for 26 epoch(s).
# Epoch 123/1000
#    - Generator Train Loss: 2.8640 - Generator Validation Loss: 2.2204
#    - Discriminator Train Loss: 1.1825 - Discriminator Validation Loss: 1.3806
# No improvement for 27 epoch(s).
# Epoch 124/1000
#    - Generator Train Loss: 2.9923 - Generator Validation Loss: 3.3689
#    - Discriminator Train Loss: 1.1685 - Discriminator Validation Loss: 1.5798
# No improvement for 28 epoch(s).
# Epoch 125/1000
#    - Generator Train Loss: 2.8808 - Generator Validation Loss: 1.2545
#    - Discriminator Train Loss: 1.2050 - Discriminator Validation Loss: 2.3034
# Validation loss improved. Best model updated.
# Epoch 126/1000
#    - Generator Train Loss: 3.0520 - Generator Validation Loss: 1.6832
#    - Discriminator Train Loss: 1.1366 - Discriminator Validation Loss: 1.5763
# No improvement for 1 epoch(s).
# Epoch 127/1000
#    - Generator Train Loss: 3.0790 - Generator Validation Loss: 2.1896
#    - Discriminator Train Loss: 1.1437 - Discriminator Validation Loss: 1.4187
# No improvement for 2 epoch(s).
# Epoch 128/1000
#    - Generator Train Loss: 3.0432 - Generator Validation Loss: 1.7205
#    - Discriminator Train Loss: 1.1246 - Discriminator Validation Loss: 1.7247
# No improvement for 3 epoch(s).
# Epoch 129/1000
#    - Generator Train Loss: 3.3908 - Generator Validation Loss: 2.4224
#    - Discriminator Train Loss: 1.0115 - Discriminator Validation Loss: 1.3810
# No improvement for 4 epoch(s).
# Epoch 130/1000
#    - Generator Train Loss: 2.3050 - Generator Validation Loss: 2.2676
#    - Discriminator Train Loss: 1.3646 - Discriminator Validation Loss: 1.3910
# No improvement for 5 epoch(s).
# Epoch 131/1000
#    - Generator Train Loss: 3.2354 - Generator Validation Loss: 1.7747
#    - Discriminator Train Loss: 1.0558 - Discriminator Validation Loss: 1.9080
# No improvement for 6 epoch(s).
# Epoch 132/1000
#    - Generator Train Loss: 3.9533 - Generator Validation Loss: 2.4608
#    - Discriminator Train Loss: 0.8948 - Discriminator Validation Loss: 1.4390
# No improvement for 7 epoch(s).
# Epoch 133/1000
#    - Generator Train Loss: 3.9269 - Generator Validation Loss: 2.3876
#    - Discriminator Train Loss: 0.8942 - Discriminator Validation Loss: 1.6215
# No improvement for 8 epoch(s).
# Epoch 134/1000
#    - Generator Train Loss: 3.1139 - Generator Validation Loss: 2.3500
#    - Discriminator Train Loss: 1.1531 - Discriminator Validation Loss: 1.3914
# No improvement for 9 epoch(s).
# Epoch 135/1000
#    - Generator Train Loss: 3.4840 - Generator Validation Loss: 2.2582
#    - Discriminator Train Loss: 1.0087 - Discriminator Validation Loss: 1.4320
# No improvement for 10 epoch(s).
# Epoch 136/1000
#    - Generator Train Loss: 4.3418 - Generator Validation Loss: 2.0619
#    - Discriminator Train Loss: 0.7445 - Discriminator Validation Loss: 1.4184
# No improvement for 11 epoch(s).
# Epoch 137/1000
#    - Generator Train Loss: 2.4111 - Generator Validation Loss: 1.5201
#    - Discriminator Train Loss: 1.3406 - Discriminator Validation Loss: 1.6861
# No improvement for 12 epoch(s).
# Epoch 138/1000
#    - Generator Train Loss: 3.7221 - Generator Validation Loss: 2.4223
#    - Discriminator Train Loss: 0.9845 - Discriminator Validation Loss: 1.4844
# No improvement for 13 epoch(s).
# Epoch 139/1000
#    - Generator Train Loss: 4.2328 - Generator Validation Loss: 1.8909
#    - Discriminator Train Loss: 0.8425 - Discriminator Validation Loss: 1.4420
# No improvement for 14 epoch(s).
# Epoch 140/1000
#    - Generator Train Loss: 4.5413 - Generator Validation Loss: 1.8773
#    - Discriminator Train Loss: 0.7687 - Discriminator Validation Loss: 1.6828
# No improvement for 15 epoch(s).
# Epoch 141/1000
#    - Generator Train Loss: 3.0411 - Generator Validation Loss: 2.4868
#    - Discriminator Train Loss: 1.1064 - Discriminator Validation Loss: 1.2889
# No improvement for 16 epoch(s).
# Epoch 142/1000
#    - Generator Train Loss: 3.3342 - Generator Validation Loss: 1.6596
#    - Discriminator Train Loss: 0.9993 - Discriminator Validation Loss: 1.7482
# No improvement for 17 epoch(s).
# Epoch 143/1000
#    - Generator Train Loss: 4.1535 - Generator Validation Loss: 2.3761
#    - Discriminator Train Loss: 0.8897 - Discriminator Validation Loss: 1.4289
# No improvement for 18 epoch(s).
# Epoch 144/1000
#    - Generator Train Loss: 2.4240 - Generator Validation Loss: 2.2018
#    - Discriminator Train Loss: 1.3576 - Discriminator Validation Loss: 1.4005
# No improvement for 19 epoch(s).
# Epoch 145/1000
#    - Generator Train Loss: 2.3026 - Generator Validation Loss: 2.2629
#    - Discriminator Train Loss: 1.3862 - Discriminator Validation Loss: 1.3887
# No improvement for 20 epoch(s).
# Epoch 146/1000
#    - Generator Train Loss: 3.2419 - Generator Validation Loss: 2.2941
#    - Discriminator Train Loss: 1.1934 - Discriminator Validation Loss: 1.4072
# No improvement for 21 epoch(s).
# Epoch 147/1000
#    - Generator Train Loss: 4.3485 - Generator Validation Loss: 3.6542
#    - Discriminator Train Loss: 0.7529 - Discriminator Validation Loss: 1.5003
# No improvement for 22 epoch(s).
# Epoch 148/1000
#    - Generator Train Loss: 4.0464 - Generator Validation Loss: 1.5745
#    - Discriminator Train Loss: 0.9016 - Discriminator Validation Loss: 1.9400
# No improvement for 23 epoch(s).
# Epoch 149/1000
#    - Generator Train Loss: 4.5388 - Generator Validation Loss: 1.0858
#    - Discriminator Train Loss: 0.7569 - Discriminator Validation Loss: 2.8031
# Validation loss improved. Best model updated.
# Epoch 150/1000
#    - Generator Train Loss: 3.6866 - Generator Validation Loss: 2.4725
#    - Discriminator Train Loss: 1.0262 - Discriminator Validation Loss: 1.4262
# No improvement for 1 epoch(s).
# Epoch 151/1000
#    - Generator Train Loss: 3.4943 - Generator Validation Loss: 1.5248
#    - Discriminator Train Loss: 1.0386 - Discriminator Validation Loss: 1.6620
# No improvement for 2 epoch(s).
# Epoch 152/1000
#    - Generator Train Loss: 4.6891 - Generator Validation Loss: 3.8167
#    - Discriminator Train Loss: 0.7279 - Discriminator Validation Loss: 1.3473
# No improvement for 3 epoch(s).
# Epoch 153/1000
#    - Generator Train Loss: 3.0380 - Generator Validation Loss: 2.2965
#    - Discriminator Train Loss: 1.1871 - Discriminator Validation Loss: 1.4031
# No improvement for 4 epoch(s).
# Epoch 154/1000
#    - Generator Train Loss: 3.9560 - Generator Validation Loss: 1.3864
#    - Discriminator Train Loss: 0.8891 - Discriminator Validation Loss: 1.9062
# No improvement for 5 epoch(s).
# Epoch 155/1000
#    - Generator Train Loss: 4.7147 - Generator Validation Loss: 1.5766
#    - Discriminator Train Loss: 0.7478 - Discriminator Validation Loss: 1.7214
# No improvement for 6 epoch(s).
# Epoch 156/1000
#    - Generator Train Loss: 4.6201 - Generator Validation Loss: 1.5469
#    - Discriminator Train Loss: 0.7956 - Discriminator Validation Loss: 1.6649
# No improvement for 7 epoch(s).
# Epoch 157/1000
#    - Generator Train Loss: 4.0131 - Generator Validation Loss: 2.8009
#    - Discriminator Train Loss: 0.9094 - Discriminator Validation Loss: 1.3975
# No improvement for 8 epoch(s).
# Epoch 158/1000
#    - Generator Train Loss: 3.4899 - Generator Validation Loss: 2.0245
#    - Discriminator Train Loss: 0.9679 - Discriminator Validation Loss: 1.5067
# No improvement for 9 epoch(s).
# Epoch 159/1000
#    - Generator Train Loss: 4.0311 - Generator Validation Loss: 1.6690
#    - Discriminator Train Loss: 0.9083 - Discriminator Validation Loss: 1.6950
# No improvement for 10 epoch(s).
# Epoch 160/1000
#    - Generator Train Loss: 4.9891 - Generator Validation Loss: 1.6623
#    - Discriminator Train Loss: 0.7044 - Discriminator Validation Loss: 1.5685
# No improvement for 11 epoch(s).
# Epoch 161/1000
#    - Generator Train Loss: 5.1152 - Generator Validation Loss: 3.0859
#    - Discriminator Train Loss: 0.6731 - Discriminator Validation Loss: 1.2373
# No improvement for 12 epoch(s).
# Epoch 162/1000
#    - Generator Train Loss: 5.2460 - Generator Validation Loss: 1.7149
#    - Discriminator Train Loss: 0.6242 - Discriminator Validation Loss: 1.5474
# No improvement for 13 epoch(s).
# Epoch 163/1000
#    - Generator Train Loss: 2.9095 - Generator Validation Loss: 2.1582
#    - Discriminator Train Loss: 1.2279 - Discriminator Validation Loss: 1.4095
# No improvement for 14 epoch(s).
# Epoch 164/1000
#    - Generator Train Loss: 3.5746 - Generator Validation Loss: 1.0277
#    - Discriminator Train Loss: 1.0839 - Discriminator Validation Loss: 2.9622
# Validation loss improved. Best model updated.
# Epoch 165/1000
#    - Generator Train Loss: 5.0650 - Generator Validation Loss: 2.3807
#    - Discriminator Train Loss: 0.6794 - Discriminator Validation Loss: 1.3965
# No improvement for 1 epoch(s).
# Epoch 166/1000
#    - Generator Train Loss: 3.7097 - Generator Validation Loss: 3.1071
#    - Discriminator Train Loss: 1.0607 - Discriminator Validation Loss: 1.2570
# No improvement for 2 epoch(s).
# Epoch 167/1000
#    - Generator Train Loss: 3.8104 - Generator Validation Loss: 2.3656
#    - Discriminator Train Loss: 1.0270 - Discriminator Validation Loss: 1.3633
# No improvement for 3 epoch(s).
# Epoch 168/1000
#    - Generator Train Loss: 4.6823 - Generator Validation Loss: 1.2587
#    - Discriminator Train Loss: 0.7531 - Discriminator Validation Loss: 2.0724
# No improvement for 4 epoch(s).
# Epoch 169/1000
#    - Generator Train Loss: 3.3570 - Generator Validation Loss: 2.3960
#    - Discriminator Train Loss: 1.1577 - Discriminator Validation Loss: 1.4545
# No improvement for 5 epoch(s).
# Epoch 170/1000
#    - Generator Train Loss: 4.3124 - Generator Validation Loss: 1.3634
#    - Discriminator Train Loss: 0.8592 - Discriminator Validation Loss: 1.8904
# No improvement for 6 epoch(s).
# Epoch 171/1000
#    - Generator Train Loss: 4.8606 - Generator Validation Loss: 1.4559
#    - Discriminator Train Loss: 0.7612 - Discriminator Validation Loss: 1.8499
# No improvement for 7 epoch(s).
# Epoch 172/1000
#    - Generator Train Loss: 5.0925 - Generator Validation Loss: 1.1899
#    - Discriminator Train Loss: 0.6247 - Discriminator Validation Loss: 2.2659
# No improvement for 8 epoch(s).
# Epoch 173/1000
#    - Generator Train Loss: 4.8362 - Generator Validation Loss: 2.7703
#    - Discriminator Train Loss: 0.7746 - Discriminator Validation Loss: 1.3552
# No improvement for 9 epoch(s).
# Epoch 174/1000
#    - Generator Train Loss: 4.6452 - Generator Validation Loss: 2.4797
#    - Discriminator Train Loss: 0.8099 - Discriminator Validation Loss: 1.3458
# No improvement for 10 epoch(s).
# Epoch 175/1000
#    - Generator Train Loss: 4.3270 - Generator Validation Loss: 2.8934
#    - Discriminator Train Loss: 0.8422 - Discriminator Validation Loss: 1.3021
# No improvement for 11 epoch(s).
# Epoch 176/1000
#    - Generator Train Loss: 4.7037 - Generator Validation Loss: 1.0260
#    - Discriminator Train Loss: 0.6995 - Discriminator Validation Loss: 3.4936
# Validation loss improved. Best model updated.
# Epoch 177/1000
#    - Generator Train Loss: 3.6992 - Generator Validation Loss: 2.1442
#    - Discriminator Train Loss: 1.0004 - Discriminator Validation Loss: 1.5459
# No improvement for 1 epoch(s).
# Epoch 178/1000
#    - Generator Train Loss: 5.3060 - Generator Validation Loss: 2.9223
#    - Discriminator Train Loss: 0.6503 - Discriminator Validation Loss: 1.4455
# No improvement for 2 epoch(s).
# Epoch 179/1000
#    - Generator Train Loss: 2.5952 - Generator Validation Loss: 2.1962
#    - Discriminator Train Loss: 1.3077 - Discriminator Validation Loss: 1.4068
# No improvement for 3 epoch(s).
# Epoch 180/1000
#    - Generator Train Loss: 4.2063 - Generator Validation Loss: 1.3034
#    - Discriminator Train Loss: 0.9685 - Discriminator Validation Loss: 1.9862
# No improvement for 4 epoch(s).
# Epoch 181/1000
#    - Generator Train Loss: 4.6812 - Generator Validation Loss: 1.6822
#    - Discriminator Train Loss: 0.8207 - Discriminator Validation Loss: 1.5675
# No improvement for 5 epoch(s).
# Epoch 182/1000
#    - Generator Train Loss: 5.0575 - Generator Validation Loss: 1.3593
#    - Discriminator Train Loss: 0.7594 - Discriminator Validation Loss: 1.9863
# No improvement for 6 epoch(s).
# Epoch 183/1000
#    - Generator Train Loss: 4.8857 - Generator Validation Loss: 0.9781
#    - Discriminator Train Loss: 0.7823 - Discriminator Validation Loss: 3.7709
# Validation loss improved. Best model updated.
# Epoch 184/1000
#    - Generator Train Loss: 4.7569 - Generator Validation Loss: 1.8214
#    - Discriminator Train Loss: 0.8035 - Discriminator Validation Loss: 1.4318
# No improvement for 1 epoch(s).
# Epoch 185/1000
#    - Generator Train Loss: 5.0426 - Generator Validation Loss: 1.9969
#    - Discriminator Train Loss: 0.7363 - Discriminator Validation Loss: 1.3905
# No improvement for 2 epoch(s).
# Epoch 186/1000
#    - Generator Train Loss: 5.4015 - Generator Validation Loss: 1.3249
#    - Discriminator Train Loss: 0.5662 - Discriminator Validation Loss: 2.0014
# No improvement for 3 epoch(s).
# Epoch 187/1000
#    - Generator Train Loss: 5.9961 - Generator Validation Loss: 1.5922
#    - Discriminator Train Loss: 0.4488 - Discriminator Validation Loss: 1.8105
# No improvement for 4 epoch(s).
# Epoch 188/1000
#    - Generator Train Loss: 4.3100 - Generator Validation Loss: 1.0620
#    - Discriminator Train Loss: 0.9090 - Discriminator Validation Loss: 2.9691
# No improvement for 5 epoch(s).
# Epoch 189/1000
#    - Generator Train Loss: 5.0106 - Generator Validation Loss: 2.4939
#    - Discriminator Train Loss: 0.6644 - Discriminator Validation Loss: 1.4162
# No improvement for 6 epoch(s).
# Epoch 190/1000
#    - Generator Train Loss: 2.7668 - Generator Validation Loss: 2.2784
#    - Discriminator Train Loss: 1.2935 - Discriminator Validation Loss: 1.7086
# No improvement for 7 epoch(s).
# Epoch 191/1000
#    - Generator Train Loss: 5.3920 - Generator Validation Loss: 3.1489
#    - Discriminator Train Loss: 0.5595 - Discriminator Validation Loss: 1.6542
# No improvement for 8 epoch(s).
# Epoch 192/1000
#    - Generator Train Loss: 4.3700 - Generator Validation Loss: 1.7140
#    - Discriminator Train Loss: 0.8632 - Discriminator Validation Loss: 1.7624
# No improvement for 9 epoch(s).
# Epoch 193/1000
#    - Generator Train Loss: 4.7613 - Generator Validation Loss: 1.1602
#    - Discriminator Train Loss: 0.7085 - Discriminator Validation Loss: 2.4007
# No improvement for 10 epoch(s).
# Epoch 194/1000
#    - Generator Train Loss: 5.1094 - Generator Validation Loss: 1.0242
#    - Discriminator Train Loss: 0.6617 - Discriminator Validation Loss: 3.2941
# No improvement for 11 epoch(s).
# Epoch 195/1000
#    - Generator Train Loss: 6.0981 - Generator Validation Loss: 3.0161
#    - Discriminator Train Loss: 0.4731 - Discriminator Validation Loss: 1.4798
# No improvement for 12 epoch(s).
# Epoch 196/1000
#    - Generator Train Loss: 5.6824 - Generator Validation Loss: 1.7597
#    - Discriminator Train Loss: 0.6997 - Discriminator Validation Loss: 1.7940
# No improvement for 13 epoch(s).
# Epoch 197/1000
#    - Generator Train Loss: 5.0438 - Generator Validation Loss: 1.3398
#    - Discriminator Train Loss: 0.6863 - Discriminator Validation Loss: 2.2137
# No improvement for 14 epoch(s).
# Epoch 198/1000
#    - Generator Train Loss: 4.4501 - Generator Validation Loss: 2.5112
#    - Discriminator Train Loss: 0.8216 - Discriminator Validation Loss: 1.4456
# No improvement for 15 epoch(s).
# Epoch 199/1000
#    - Generator Train Loss: 5.0076 - Generator Validation Loss: 1.3286
#    - Discriminator Train Loss: 0.6651 - Discriminator Validation Loss: 2.0228
# No improvement for 16 epoch(s).
# Epoch 200/1000
#    - Generator Train Loss: 5.5944 - Generator Validation Loss: 1.3966
#    - Discriminator Train Loss: 0.6164 - Discriminator Validation Loss: 1.8963
# No improvement for 17 epoch(s).
# Epoch 201/1000
#    - Generator Train Loss: 4.1918 - Generator Validation Loss: 2.0314
#    - Discriminator Train Loss: 1.0121 - Discriminator Validation Loss: 1.5379
# No improvement for 18 epoch(s).
# Epoch 202/1000
#    - Generator Train Loss: 3.8154 - Generator Validation Loss: 0.9453
#    - Discriminator Train Loss: 0.9508 - Discriminator Validation Loss: 4.1478
# Validation loss improved. Best model updated.
# Epoch 203/1000
#    - Generator Train Loss: 6.2963 - Generator Validation Loss: 2.2417
#    - Discriminator Train Loss: 0.4934 - Discriminator Validation Loss: 1.5553
# No improvement for 1 epoch(s).
# Epoch 204/1000
#    - Generator Train Loss: 5.6352 - Generator Validation Loss: 2.1407
#    - Discriminator Train Loss: 0.5886 - Discriminator Validation Loss: 1.3650
# No improvement for 2 epoch(s).
# Epoch 205/1000
#    - Generator Train Loss: 5.5163 - Generator Validation Loss: 0.9902
#    - Discriminator Train Loss: 0.6403 - Discriminator Validation Loss: 3.7923
# No improvement for 3 epoch(s).
# Epoch 206/1000
#    - Generator Train Loss: 5.7207 - Generator Validation Loss: 2.3119
#    - Discriminator Train Loss: 0.5709 - Discriminator Validation Loss: 1.9755
# No improvement for 4 epoch(s).
# Epoch 207/1000
#    - Generator Train Loss: 5.3382 - Generator Validation Loss: 3.0698
#    - Discriminator Train Loss: 0.6811 - Discriminator Validation Loss: 1.4280
# No improvement for 5 epoch(s).
# Epoch 208/1000
#    - Generator Train Loss: 2.7100 - Generator Validation Loss: 2.3446
#    - Discriminator Train Loss: 1.2440 - Discriminator Validation Loss: 1.4810
# No improvement for 6 epoch(s).
# Epoch 209/1000
#    - Generator Train Loss: 5.8087 - Generator Validation Loss: 1.3431
#    - Discriminator Train Loss: 0.5264 - Discriminator Validation Loss: 2.0366
# No improvement for 7 epoch(s).
# Epoch 210/1000
#    - Generator Train Loss: 6.1123 - Generator Validation Loss: 0.9665
#    - Discriminator Train Loss: 0.3984 - Discriminator Validation Loss: 3.8960
# No improvement for 8 epoch(s).
# Epoch 211/1000
#    - Generator Train Loss: 6.2087 - Generator Validation Loss: 0.9481
#    - Discriminator Train Loss: 0.5562 - Discriminator Validation Loss: 5.0063
# No improvement for 9 epoch(s).
# Epoch 212/1000
#    - Generator Train Loss: 5.7865 - Generator Validation Loss: 1.5895
#    - Discriminator Train Loss: 0.5641 - Discriminator Validation Loss: 2.0075
# No improvement for 10 epoch(s).
# Epoch 213/1000
#    - Generator Train Loss: 5.4044 - Generator Validation Loss: 1.0665
#    - Discriminator Train Loss: 0.6368 - Discriminator Validation Loss: 2.8626
# No improvement for 11 epoch(s).
# Epoch 214/1000
#    - Generator Train Loss: 5.5675 - Generator Validation Loss: 1.0198
#    - Discriminator Train Loss: 0.4753 - Discriminator Validation Loss: 3.3758
# No improvement for 12 epoch(s).
# Epoch 215/1000
#    - Generator Train Loss: 6.1644 - Generator Validation Loss: 1.1769
#    - Discriminator Train Loss: 0.4785 - Discriminator Validation Loss: 3.1462
# No improvement for 13 epoch(s).
# Epoch 216/1000
#    - Generator Train Loss: 6.2536 - Generator Validation Loss: 3.2010
#    - Discriminator Train Loss: 0.5164 - Discriminator Validation Loss: 1.4175
# No improvement for 14 epoch(s).
# Epoch 217/1000
#    - Generator Train Loss: 5.8579 - Generator Validation Loss: 0.9762
#    - Discriminator Train Loss: 0.5245 - Discriminator Validation Loss: 3.6918
# No improvement for 15 epoch(s).
# Epoch 218/1000
#    - Generator Train Loss: 6.0171 - Generator Validation Loss: 1.4233
#    - Discriminator Train Loss: 0.5121 - Discriminator Validation Loss: 1.8185
# No improvement for 16 epoch(s).
# Epoch 219/1000
#    - Generator Train Loss: 5.0275 - Generator Validation Loss: 1.0074
#    - Discriminator Train Loss: 0.7382 - Discriminator Validation Loss: 3.5324
# No improvement for 17 epoch(s).
# Epoch 220/1000
#    - Generator Train Loss: 6.9627 - Generator Validation Loss: 1.7550
#    - Discriminator Train Loss: 0.4601 - Discriminator Validation Loss: 1.7030
# No improvement for 18 epoch(s).
# Epoch 221/1000
#    - Generator Train Loss: 6.2753 - Generator Validation Loss: 0.9556
#    - Discriminator Train Loss: 0.3772 - Discriminator Validation Loss: 4.0534
# No improvement for 19 epoch(s).
# Epoch 222/1000
#    - Generator Train Loss: 5.9139 - Generator Validation Loss: 0.9595
#    - Discriminator Train Loss: 0.5793 - Discriminator Validation Loss: 4.0863
# No improvement for 20 epoch(s).
# Epoch 223/1000
#    - Generator Train Loss: 5.9883 - Generator Validation Loss: 1.2468
#    - Discriminator Train Loss: 0.6107 - Discriminator Validation Loss: 2.2818
# ...
# No improvement for 26 epoch(s).
# Epoch 300/1000
#    - Generator Train Loss: 7.2929 - Generator Validation Loss: 0.9724
#    - Discriminator Train Loss: 0.3258 - Discriminator Validation Loss: 5.1507
# No improvement for 27 epoch(s).
# Epoch 301/1000
#    - Generator Train Loss: 6.9602 - Generator Validation Loss: 1.7307
#    - Discriminator Train Loss: 0.4430 - Discriminator Validation Loss: 1.9090
# No improvement for 28 epoch(s).
# Epoch 302/1000
#    - Generator Train Loss: 6.5863 - Generator Validation Loss: 0.9920
#    - Discriminator Train Loss: 0.4255 - Discriminator Validation Loss: 3.6970
# No improvement for 29 epoch(s).
# Epoch 303/1000
#    - Generator Train Loss: 6.6178 - Generator Validation Loss: 1.6401
#    - Discriminator Train Loss: 0.3778 - Discriminator Validation Loss: 1.6570
# No improvement for 30 epoch(s).
# Epoch 304/1000
#    - Generator Train Loss: 7.1484 - Generator Validation Loss: 1.0537
#    - Discriminator Train Loss: 0.3835 - Discriminator Validation Loss: 3.1645
# No improvement for 31 epoch(s).
# Epoch 305/1000
#    - Generator Train Loss: 7.1082 - Generator Validation Loss: 0.9407
#    - Discriminator Train Loss: 0.3531 - Discriminator Validation Loss: 5.3437
# No improvement for 32 epoch(s).
# Epoch 306/1000
#    - Generator Train Loss: 7.2336 - Generator Validation Loss: 0.9955
#    - Discriminator Train Loss: 0.4087 - Discriminator Validation Loss: 4.6396
# No improvement for 33 epoch(s).
# Epoch 307/1000
#    - Generator Train Loss: 6.7353 - Generator Validation Loss: 1.0048
#    - Discriminator Train Loss: 0.3892 - Discriminator Validation Loss: 3.4530
# No improvement for 34 epoch(s).
# Epoch 308/1000
#    - Generator Train Loss: 6.6686 - Generator Validation Loss: 1.4502
#    - Discriminator Train Loss: 0.4763 - Discriminator Validation Loss: 1.9732
# No improvement for 35 epoch(s).
# Epoch 309/1000
#    - Generator Train Loss: 6.8638 - Generator Validation Loss: 0.9695
#    - Discriminator Train Loss: 0.3744 - Discriminator Validation Loss: 4.0367
# No improvement for 36 epoch(s).
# Epoch 310/1000
#    - Generator Train Loss: 7.4024 - Generator Validation Loss: 1.3482
#    - Discriminator Train Loss: 0.3760 - Discriminator Validation Loss: 2.0072
# No improvement for 37 epoch(s).
# Epoch 311/1000
#    - Generator Train Loss: 6.9726 - Generator Validation Loss: 1.1069
#    - Discriminator Train Loss: 0.4125 - Discriminator Validation Loss: 2.5331
# No improvement for 38 epoch(s).
# Epoch 312/1000
#    - Generator Train Loss: 6.3082 - Generator Validation Loss: 2.0333
#    - Discriminator Train Loss: 0.6877 - Discriminator Validation Loss: 1.6979
# No improvement for 39 epoch(s).
# Epoch 313/1000
#    - Generator Train Loss: 7.1043 - Generator Validation Loss: 0.9989
#    - Discriminator Train Loss: 0.3053 - Discriminator Validation Loss: 3.7984
# No improvement for 40 epoch(s).
# Epoch 314/1000
#    - Generator Train Loss: 7.9543 - Generator Validation Loss: 0.9723
#    - Discriminator Train Loss: 0.2763 - Discriminator Validation Loss: 4.4912
# No improvement for 41 epoch(s).
# Epoch 315/1000
#    - Generator Train Loss: 7.3788 - Generator Validation Loss: 0.9796
#    - Discriminator Train Loss: 0.2973 - Discriminator Validation Loss: 4.0460
# No improvement for 42 epoch(s).
# Epoch 316/1000
#    - Generator Train Loss: 7.4324 - Generator Validation Loss: 2.5340
#    - Discriminator Train Loss: 0.4101 - Discriminator Validation Loss: 0.9737
# No improvement for 43 epoch(s).
# Epoch 317/1000
#    - Generator Train Loss: 6.3428 - Generator Validation Loss: 2.9678
#    - Discriminator Train Loss: 0.4946 - Discriminator Validation Loss: 1.4491
# No improvement for 44 epoch(s).
# Epoch 318/1000
#    - Generator Train Loss: 7.1142 - Generator Validation Loss: 1.0118
#    - Discriminator Train Loss: 0.3936 - Discriminator Validation Loss: 3.9931
# No improvement for 45 epoch(s).
# Epoch 319/1000
#    - Generator Train Loss: 6.8384 - Generator Validation Loss: 0.9931
#    - Discriminator Train Loss: 0.5647 - Discriminator Validation Loss: 4.0781
# No improvement for 46 epoch(s).
# Epoch 320/1000
#    - Generator Train Loss: 6.5680 - Generator Validation Loss: 1.0414
#    - Discriminator Train Loss: 0.4421 - Discriminator Validation Loss: 3.3357
# No improvement for 47 epoch(s).
# Epoch 321/1000
#    - Generator Train Loss: 6.7632 - Generator Validation Loss: 0.9439
#    - Discriminator Train Loss: 0.4123 - Discriminator Validation Loss: 5.2892
# No improvement for 48 epoch(s).
# Epoch 322/1000
#    - Generator Train Loss: 7.3194 - Generator Validation Loss: 1.1624
#    - Discriminator Train Loss: 0.2983 - Discriminator Validation Loss: 2.5789
# No improvement for 49 epoch(s).
# Epoch 323/1000
#    - Generator Train Loss: 7.3978 - Generator Validation Loss: 0.9967
#    - Discriminator Train Loss: 0.3351 - Discriminator Validation Loss: 3.7328
# No improvement for 50 epoch(s).
# Epoch 324/1000
#    - Generator Train Loss: 6.9269 - Generator Validation Loss: 0.9063
#    - Discriminator Train Loss: 0.4290 - Discriminator Validation Loss: 5.0960
# No improvement for 51 epoch(s).
# Epoch 325/1000
#    - Generator Train Loss: 7.5335 - Generator Validation Loss: 0.9818
#    - Discriminator Train Loss: 0.3525 - Discriminator Validation Loss: 4.4008
# No improvement for 52 epoch(s).
# Epoch 326/1000
#    - Generator Train Loss: 7.3325 - Generator Validation Loss: 0.9905
#    - Discriminator Train Loss: 0.3241 - Discriminator Validation Loss: 4.3628
# No improvement for 53 epoch(s).
# Epoch 327/1000
#    - Generator Train Loss: 7.7138 - Generator Validation Loss: 1.1755
#    - Discriminator Train Loss: 0.2892 - Discriminator Validation Loss: 2.8179
# No improvement for 54 epoch(s).
# Epoch 328/1000
#    - Generator Train Loss: 6.4928 - Generator Validation Loss: 0.9772
#    - Discriminator Train Loss: 0.5806 - Discriminator Validation Loss: 4.9987
# No improvement for 55 epoch(s).
# Epoch 329/1000
#    - Generator Train Loss: 6.9357 - Generator Validation Loss: 2.7609
#    - Discriminator Train Loss: 0.4682 - Discriminator Validation Loss: 1.6625
# No improvement for 56 epoch(s).
# Epoch 330/1000
#    - Generator Train Loss: 6.7805 - Generator Validation Loss: 1.6719
#    - Discriminator Train Loss: 0.4247 - Discriminator Validation Loss: 2.3627
# No improvement for 57 epoch(s).
# Epoch 331/1000
#    - Generator Train Loss: 7.3478 - Generator Validation Loss: 1.1901
#    - Discriminator Train Loss: 0.3508 - Discriminator Validation Loss: 2.4451
# No improvement for 58 epoch(s).
# Epoch 332/1000
#    - Generator Train Loss: 7.4437 - Generator Validation Loss: 1.4076
#    - Discriminator Train Loss: 0.4611 - Discriminator Validation Loss: 2.0277
# No improvement for 59 epoch(s).
# Epoch 333/1000
#    - Generator Train Loss: 7.4199 - Generator Validation Loss: 1.2992
#    - Discriminator Train Loss: 0.3776 - Discriminator Validation Loss: 2.1502
# No improvement for 60 epoch(s).
# Epoch 334/1000
#    - Generator Train Loss: 7.0610 - Generator Validation Loss: 0.9719
#    - Discriminator Train Loss: 0.3814 - Discriminator Validation Loss: 4.9770
# No improvement for 61 epoch(s).
# Epoch 335/1000
#    - Generator Train Loss: 6.9165 - Generator Validation Loss: 1.0456
#    - Discriminator Train Loss: 0.4578 - Discriminator Validation Loss: 2.9414
# No improvement for 62 epoch(s).
# Epoch 336/1000
#    - Generator Train Loss: 7.1895 - Generator Validation Loss: 1.2541
#    - Discriminator Train Loss: 0.3705 - Discriminator Validation Loss: 2.2579
# No improvement for 63 epoch(s).
# Epoch 337/1000
#    - Generator Train Loss: 7.3117 - Generator Validation Loss: 1.2296
#    - Discriminator Train Loss: 0.3242 - Discriminator Validation Loss: 2.2983
# No improvement for 64 epoch(s).
# Epoch 338/1000
#    - Generator Train Loss: 7.1725 - Generator Validation Loss: 0.9466
#    - Discriminator Train Loss: 0.3077 - Discriminator Validation Loss: 6.1703
# No improvement for 65 epoch(s).
# Epoch 339/1000
#    - Generator Train Loss: 7.7933 - Generator Validation Loss: 1.0010
#    - Discriminator Train Loss: 0.3561 - Discriminator Validation Loss: 3.7559
# No improvement for 66 epoch(s).
# Epoch 340/1000
#    - Generator Train Loss: 6.3440 - Generator Validation Loss: 1.0335
#    - Discriminator Train Loss: 0.6512 - Discriminator Validation Loss: 3.0638
# No improvement for 67 epoch(s).
# Epoch 341/1000
#    - Generator Train Loss: 6.5871 - Generator Validation Loss: 0.9133
#    - Discriminator Train Loss: 0.4259 - Discriminator Validation Loss: 5.7774
# No improvement for 68 epoch(s).
# Epoch 342/1000
#    - Generator Train Loss: 7.1369 - Generator Validation Loss: 2.2887
#    - Discriminator Train Loss: 0.4217 - Discriminator Validation Loss: 1.6602
# No improvement for 69 epoch(s).
# Epoch 343/1000
#    - Generator Train Loss: 6.9094 - Generator Validation Loss: 0.9752
#    - Discriminator Train Loss: 0.3517 - Discriminator Validation Loss: 3.5680
# No improvement for 70 epoch(s).
# Epoch 344/1000
#    - Generator Train Loss: 7.5123 - Generator Validation Loss: 0.9583
#    - Discriminator Train Loss: 0.4570 - Discriminator Validation Loss: 4.3165
# No improvement for 71 epoch(s).
# Epoch 345/1000
#    - Generator Train Loss: 7.5686 - Generator Validation Loss: 1.0287
#    - Discriminator Train Loss: 0.2513 - Discriminator Validation Loss: 4.2177
# No improvement for 72 epoch(s).
# Epoch 346/1000
#    - Generator Train Loss: 6.5517 - Generator Validation Loss: 0.9238
#    - Discriminator Train Loss: 0.5571 - Discriminator Validation Loss: 4.9297
# No improvement for 73 epoch(s).
# Epoch 347/1000
#    - Generator Train Loss: 7.8051 - Generator Validation Loss: 0.9217
#    - Discriminator Train Loss: 0.3560 - Discriminator Validation Loss: 5.2248
# No improvement for 74 epoch(s).
# Epoch 348/1000
#    - Generator Train Loss: 7.3069 - Generator Validation Loss: 0.9418
#    - Discriminator Train Loss: 0.3433 - Discriminator Validation Loss: 4.7512
# No improvement for 75 epoch(s).
# Epoch 349/1000
#    - Generator Train Loss: 8.6435 - Generator Validation Loss: 0.9396
#    - Discriminator Train Loss: 0.2255 - Discriminator Validation Loss: 4.9710
# No improvement for 76 epoch(s).
# Epoch 350/1000
#    - Generator Train Loss: 8.5710 - Generator Validation Loss: 0.9308
#    - Discriminator Train Loss: 0.3296 - Discriminator Validation Loss: 5.0384
# No improvement for 77 epoch(s).
# Epoch 351/1000
#    - Generator Train Loss: 7.2205 - Generator Validation Loss: 1.0115
#    - Discriminator Train Loss: 0.3700 - Discriminator Validation Loss: 4.1328
# No improvement for 78 epoch(s).
# Epoch 352/1000
#    - Generator Train Loss: 7.4135 - Generator Validation Loss: 1.4290
#    - Discriminator Train Loss: 0.3748 - Discriminator Validation Loss: 1.8669
# No improvement for 79 epoch(s).
# Epoch 353/1000
#    - Generator Train Loss: 8.2240 - Generator Validation Loss: 1.0724
#    - Discriminator Train Loss: 0.2515 - Discriminator Validation Loss: 3.0907
# No improvement for 80 epoch(s).
# Epoch 354/1000
#    - Generator Train Loss: 6.8318 - Generator Validation Loss: 1.5795
#    - Discriminator Train Loss: 0.6988 - Discriminator Validation Loss: 1.9312
# No improvement for 81 epoch(s).
# Epoch 355/1000
#    - Generator Train Loss: 6.6047 - Generator Validation Loss: 0.9479
#    - Discriminator Train Loss: 0.4480 - Discriminator Validation Loss: 5.1922
# No improvement for 82 epoch(s).
# Epoch 356/1000
#    - Generator Train Loss: 7.6386 - Generator Validation Loss: 1.0288
#    - Discriminator Train Loss: 0.3886 - Discriminator Validation Loss: 3.5104
# No improvement for 83 epoch(s).
# Epoch 357/1000
#    - Generator Train Loss: 7.1392 - Generator Validation Loss: 0.9389
#    - Discriminator Train Loss: 0.3839 - Discriminator Validation Loss: 4.1913
# No improvement for 84 epoch(s).
# Epoch 358/1000
#    - Generator Train Loss: 7.5615 - Generator Validation Loss: 1.0540
#    - Discriminator Train Loss: 0.3798 - Discriminator Validation Loss: 3.0116
# No improvement for 85 epoch(s).
# Epoch 359/1000
#    - Generator Train Loss: 7.8467 - Generator Validation Loss: 0.9365
#    - Discriminator Train Loss: 0.2855 - Discriminator Validation Loss: 5.5610
# No improvement for 86 epoch(s).
# Epoch 360/1000
#    - Generator Train Loss: 7.1131 - Generator Validation Loss: 1.0207
#    - Discriminator Train Loss: 0.3713 - Discriminator Validation Loss: 3.7366
# No improvement for 87 epoch(s).
# Epoch 361/1000
#    - Generator Train Loss: 7.5898 - Generator Validation Loss: 0.9967
#    - Discriminator Train Loss: 0.3332 - Discriminator Validation Loss: 4.0091
# No improvement for 88 epoch(s).
# Epoch 362/1000
#    - Generator Train Loss: 8.0272 - Generator Validation Loss: 1.0826
#    - Discriminator Train Loss: 0.3502 - Discriminator Validation Loss: 2.8675
# No improvement for 89 epoch(s).
# Epoch 363/1000
#    - Generator Train Loss: 7.8385 - Generator Validation Loss: 0.9321
#    - Discriminator Train Loss: 0.2844 - Discriminator Validation Loss: 4.4078
# No improvement for 90 epoch(s).
# Epoch 364/1000
#    - Generator Train Loss: 7.2861 - Generator Validation Loss: 0.9814
#    - Discriminator Train Loss: 0.4470 - Discriminator Validation Loss: 3.9554
# No improvement for 91 epoch(s).
# Epoch 365/1000
#    - Generator Train Loss: 7.0223 - Generator Validation Loss: 1.0149
#    - Discriminator Train Loss: 0.4256 - Discriminator Validation Loss: 3.3822
# No improvement for 92 epoch(s).
# Epoch 366/1000
#    - Generator Train Loss: 7.5910 - Generator Validation Loss: 2.8603
#    - Discriminator Train Loss: 0.3553 - Discriminator Validation Loss: 1.3790
# No improvement for 93 epoch(s).
# Epoch 367/1000
#    - Generator Train Loss: 7.1033 - Generator Validation Loss: 0.9828
#    - Discriminator Train Loss: 0.3835 - Discriminator Validation Loss: 4.0107
# No improvement for 94 epoch(s).
# Epoch 368/1000
#    - Generator Train Loss: 7.6892 - Generator Validation Loss: 1.0527
#    - Discriminator Train Loss: 0.3312 - Discriminator Validation Loss: 3.2098
# No improvement for 95 epoch(s).
# Epoch 369/1000
#    - Generator Train Loss: 8.1681 - Generator Validation Loss: 1.1941
#    - Discriminator Train Loss: 0.3013 - Discriminator Validation Loss: 2.4831
# No improvement for 96 epoch(s).
# Epoch 370/1000
#    - Generator Train Loss: 7.1467 - Generator Validation Loss: 0.9856
#    - Discriminator Train Loss: 0.3827 - Discriminator Validation Loss: 3.7884
# No improvement for 97 epoch(s).
# Epoch 371/1000
#    - Generator Train Loss: 8.1570 - Generator Validation Loss: 1.2851
#    - Discriminator Train Loss: 0.2502 - Discriminator Validation Loss: 2.5098
# No improvement for 98 epoch(s).
# Epoch 372/1000
#    - Generator Train Loss: 7.3629 - Generator Validation Loss: 0.9975
#    - Discriminator Train Loss: 0.4469 - Discriminator Validation Loss: 3.7509
# No improvement for 99 epoch(s).
# Epoch 373/1000
#    - Generator Train Loss: 8.1095 - Generator Validation Loss: 1.3778
#    - Discriminator Train Loss: 0.3504 - Discriminator Validation Loss: 1.9469
# No improvement for 100 epoch(s).
# Early stopping triggered!

# %%
# save the best model
os.makedirs('./gen_models/models', exist_ok=True)
if gen_best_model_state is not None:
    torch.save(gen_best_model_state, gen_best_model_filename)
    print(f"Best model saved to {gen_best_model_filename}")
# Out:
# Best model saved to ./gen_models/best_model_0.8960700082151514_20250428_015556.pth

# %% [markdown]
# # Model Testing

# %%
generator.load_state_dict(torch.load(gen_best_model_filename, map_location=device, weights_only=True))
generator.eval()

# Arrays to store all predictions and all ground truth masks
pred_mask_all, target_all = [], []

with torch.no_grad():
    for batch in test_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)

        # Make test predictions
        pred_mask = generator(images)

        pred_mask_all.append(pred_mask.cpu().numpy())
        target_all.append(target.cpu().numpy())

    # Concatenate all batches into a single array for performance                        
    preds = np.concatenate(pred_mask_all, axis=0)   
    trues = np.concatenate(target_all, axis=0)        

    # Squeeze from 4 dimensions into 3 since we use only one channel
    if preds.ndim == 4 and preds.shape[1] == 1:
        preds = preds.squeeze(1)
        trues = trues.squeeze(1)

    # Binarize predictions
    preds  = (preds > 0.5).astype(np.uint8)
    trues  = trues.astype(np.uint8)

    preds = preds.flatten()
    trues = trues.flatten()

    # Calculate TP, FP, FN for evaluation metrics
    tp = np.logical_and(preds==1, trues==1).sum()
    fp = np.logical_and(preds==1, trues==0).sum()
    fn = np.logical_and(preds==0, trues==1).sum()

    # Calculate evaluation metrics
    smooth = 1e-6
    dice = (2*tp + smooth) / (2*tp + fp + fn + smooth)
    iou  = (tp + smooth)   / (tp + fp + fn + smooth)
    recall = tp / (tp + fn + smooth)

                             
    # Dice coefficient
    # IoU (Jaccard Index)
    # Recall - We care a lot about false negatives
    metrics = {
        'Dice Coefficient': dice,
        'IoU': iou,
        'Recall': recall
        }
    
    print("\n **Test Results:**")
    for key, value in metrics.items():
        print(f"{key}: {value:.4f}")
# Out:
#  **Test Results:**
# Dice Coefficient: 0.0788
# IoU: 0.0410
# Recall: 0.4675

# %%
img, lab = next(iter(test_loader))
pred = generator(img.to(device))

# %%
tensor_np = pred[1][0].detach().cpu().numpy()

plt.imshow(tensor_np, cmap='gray')
plt.colorbar()
plt.show()

# %%
tensor_np = lab[1][0].detach().cpu().numpy()

plt.imshow(tensor_np, cmap='gray')
plt.colorbar()
plt.show()
