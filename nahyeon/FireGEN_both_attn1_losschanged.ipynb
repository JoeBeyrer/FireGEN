# %%
from utils import *
from models import *
from loss import *
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import colors
from datetime import datetime

# %%
train_path = '../next_day_fires/next_day_wildfire_spread_train*'
val_path = '../next_day_fires/next_day_wildfire_spread_eval*'
test_path = '../next_day_fires/next_day_wildfire_spread_test*'
features = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask', 'FireMask']

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Training Data

# %%
train_dataset = get_dataset(
      train_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

train_inputs, train_labels = next(iter(train_dataset))

print(train_inputs.shape)
print(train_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
titles = [
  'Elevation',
  'Wind\ndirection',
  'Wind\nvelocity',
  'Min\ntemp',
  'Max\ntemp',
  'Humidity',
  'Precip',
  'Drought',
  'Vegetation',
  'Population\ndensity',
  'Energy\nrelease\ncomponent',
  'Previous\nfire\nmask',
  'Fire\nmask'
]

n_rows = 5
n_features = train_inputs.shape[3] 
CMAP = colors.ListedColormap(['black', 'silver', 'orangered'])
BOUNDS = [-1, -0.1, 0.001, 1]
NORM = colors.BoundaryNorm(BOUNDS, CMAP.N)
keys = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask']

# %%
# fig = plt.figure(figsize=(20,8))

# for i in range(n_rows):
#   for j in range(n_features + 1):
#     plt.subplot(n_rows, n_features + 1, i * (n_features + 1) + j + 1)
#     if i == 0:
#       plt.title(titles[j], fontsize=15)
#     if j < n_features - 1:
#       plt.imshow(train_inputs[i, j, :, :], cmap='viridis')
#     if j == n_features - 1:
#       plt.imshow(train_inputs[i, -1, :, :], cmap=CMAP, norm=NORM)
#     if j == n_features:
#       plt.imshow(train_labels[i, 0, :, :], cmap=CMAP, norm=NORM) 
#     plt.axis('off')
# plt.tight_layout()

# %% [markdown]
# ## Vlidation Data

# %%
val_dataset = get_dataset(
      val_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

val_inputs, val_labels = next(iter(val_dataset))

print(val_inputs.shape)
print(val_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %% [markdown]
# ## Test Data

# %%
test_dataset = get_dataset(
      test_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

test_inputs, test_labels = next(iter(val_dataset))

print(test_inputs.shape)
print(test_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
# Build DataLoader
train_loader = DataLoader(train_dataset, batch_size=None, num_workers=0, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=None, num_workers=0, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=None, num_workers=0, pin_memory=True)

# %% [markdown]
# # Model Initialization

# %%
folder_path = './gen_models'
gen_input_channels = 12
disc_input_channels = 13
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Hyperparameters

# %%
#  Hyperparameters
kernel_size = 4 # DO NOT CHANGE
stride = 2 # DO NOT CHANGE
padding = 1 # DO NOT CHANGE
dropout = 0.5

gen_lr = 1e-4
disc_lr = 1e-4

alpha = 1
lambd = 2
pos_weight = 30
bce_weight = 0.5

num_epochs = 1000
patience = 100

# %% [markdown]
# ### Model Initialization

# %%
generator = Generator(gen_input_channels, kernel_size, stride, padding, dropout)
discriminator = Discriminator(disc_input_channels, kernel_size, stride, padding)

generator.apply(init_weights)
discriminator.apply(init_weights)

generator.to(device)
discriminator.to(device)
# Out:
# Discriminator(
#   (e1): Conv2d(13, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (lr1): LeakyReLU(negative_slope=0.2)
#   (e2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr2): LeakyReLU(negative_slope=0.2)
#   (e3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr3): LeakyReLU(negative_slope=0.2)
#   (output): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# # Model Training

# %%
gen_best_val_loss = float('inf')
epochs_no_improve = 0
gen_best_model_state = None
bgen_est_model_filename = None

# Optimizers and loss functions
gen_optimizer = torch.optim.Adam(generator.parameters(), lr=gen_lr, betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(discriminator.parameters(), lr=disc_lr, betas=(0.5, 0.999))
gen_criterion = GenLoss(alpha=alpha, lambd=lambd, pos_weight=torch.tensor([pos_weight]).to(device), bce_weight=bce_weight)
disc_criterion = DiscLoss()
torch.autograd.set_detect_anomaly(True)
# Train over the entire dataset every epoch
for epoch in range(num_epochs):
    if epoch == 50:
        gen_best_val_loss = float('inf')
        gen_criterion.alpha = 0.5
        for p in discriminator.parameters():
            p.requires_grad = True
    elif epoch == 0:
        gen_criterion.alpha = 0
        for p in discriminator.parameters():
            p.requires_grad = False
            
    generator.train()
    discriminator.train()

    gen_total_loss = 0
    disc_total_loss = 0

    # Train in batches 
    for batch in train_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)
        # Update Discriminator
        disc_optimizer.zero_grad()

        # Generate fake images
        with torch.no_grad():
            generated = generator(images)
        generated_detached = generated.detach()

        # Discriminator loss
        real_pred = discriminator(target, images)
        fake_pred = discriminator(generated_detached, images)
        disc_loss = disc_criterion(real_pred, fake_pred)

        if epoch > 49:
            disc_loss.backward()
            disc_optimizer.step()

        # Update generator
        gen_optimizer.zero_grad()

        # Re-forward generator
        generated = generator(images)
        gen_pred = discriminator(generated, images)
        gen_loss = gen_criterion(
            gen_logits=generated, 
            disc_pred=gen_pred, 
            target_mask=target
        )
        #gen_loss = gen_criterion(gen_pred, generated, target)

        gen_loss.backward()
        gen_optimizer.step()

        # Add loss to totals
        gen_total_loss = gen_total_loss + gen_loss.item()
        disc_total_loss = disc_total_loss + disc_loss.item()

    # Average the loss over all batches
    gen_avg_loss = gen_total_loss / len(train_loader)
    disc_avg_loss = disc_total_loss / len(train_loader)


    # Now, validate the model
    generator.eval()
    discriminator.eval()
    gen_val_loss = 0
    disc_val_loss = 0

    # Gradients are not used as validation is used to find the best model without further optimization
    with torch.no_grad():
        # Validate in batches
        for batch in val_loader:
            images, target = batch
            images = images.to(device)
            target = target.to(device)
            
            # Make predictions on the validation images
            generated = generator(images)
            gen_pred = discriminator(generated, images)
            real_pred = discriminator(target, images)

            # Calculate the loss
            #gen_loss = gen_criterion(gen_pred, generated, target)
            gen_loss = gen_criterion(
                gen_logits=generated, 
                disc_pred=gen_pred, 
                target_mask=target
            )
            disc_loss = disc_criterion(real_pred, gen_pred)
            gen_val_loss = gen_val_loss + gen_loss.item()
            disc_val_loss = disc_val_loss + disc_loss.item()


    
    # Average the validation loss over all batches
    gen_avg_val_loss = gen_val_loss / len(val_loader)
    disc_avg_val_loss = disc_val_loss / len(val_loader)
    
    
    print(f"Epoch {epoch + 1}/{num_epochs}\
          \n   - Generator Train Loss: {gen_avg_loss:.4f} - Generator Validation Loss: {gen_avg_val_loss:.4f}\
          \n   - Discriminator Train Loss: {disc_avg_loss:.4f} - Discriminator Validation Loss: {disc_avg_val_loss:.4f}")

    # Best model saving & early stopping
    if gen_avg_val_loss < gen_best_val_loss:
        gen_best_val_loss = gen_avg_val_loss
        epochs_no_improve = 0
        gen_best_model_state = generator.state_dict() 
        gen_best_model_filename = f"{folder_path}/best_model_{str(gen_best_val_loss)}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pth"
        print("Validation loss improved. Best model updated.")
    else:
        epochs_no_improve += 1
        print(f"No improvement for {epochs_no_improve} epoch(s).")
    
    if epochs_no_improve >= patience:
        print("Early stopping triggered!")
        break
# Out:
# Epoch 1/1000
#    - Generator Train Loss: 2.1514 - Generator Validation Loss: 2.1174
#    - Discriminator Train Loss: 1.4773 - Discriminator Validation Loss: 1.4808
# Validation loss improved. Best model updated.
# Epoch 2/1000
#    - Generator Train Loss: 2.1041 - Generator Validation Loss: 2.1161
#    - Discriminator Train Loss: 1.4767 - Discriminator Validation Loss: 1.4849
# Validation loss improved. Best model updated.
# Epoch 3/1000
#    - Generator Train Loss: 2.0911 - Generator Validation Loss: 2.0910
#    - Discriminator Train Loss: 1.4758 - Discriminator Validation Loss: 1.4879
# Validation loss improved. Best model updated.
# Epoch 4/1000
#    - Generator Train Loss: 2.0879 - Generator Validation Loss: 2.1394
#    - Discriminator Train Loss: 1.4755 - Discriminator Validation Loss: 1.4768
# No improvement for 1 epoch(s).
# Epoch 5/1000
#    - Generator Train Loss: 2.0829 - Generator Validation Loss: 2.1066
#    - Discriminator Train Loss: 1.4765 - Discriminator Validation Loss: 1.4794
# No improvement for 2 epoch(s).
# Epoch 6/1000
#    - Generator Train Loss: 2.0793 - Generator Validation Loss: 2.1048
#    - Discriminator Train Loss: 1.4777 - Discriminator Validation Loss: 1.4888
# No improvement for 3 epoch(s).
# Epoch 7/1000
#    - Generator Train Loss: 2.0797 - Generator Validation Loss: 2.1488
#    - Discriminator Train Loss: 1.4767 - Discriminator Validation Loss: 1.4315
# No improvement for 4 epoch(s).
# Epoch 8/1000
#    - Generator Train Loss: 2.0771 - Generator Validation Loss: 2.0578
#    - Discriminator Train Loss: 1.4767 - Discriminator Validation Loss: 1.4660
# Validation loss improved. Best model updated.
# Epoch 9/1000
#    - Generator Train Loss: 2.0748 - Generator Validation Loss: 2.0755
#    - Discriminator Train Loss: 1.4774 - Discriminator Validation Loss: 1.4818
# No improvement for 1 epoch(s).
# Epoch 10/1000
#    - Generator Train Loss: 2.0709 - Generator Validation Loss: 2.0842
#    - Discriminator Train Loss: 1.4769 - Discriminator Validation Loss: 1.4817
# No improvement for 2 epoch(s).
# Epoch 11/1000
#    - Generator Train Loss: 2.0713 - Generator Validation Loss: 2.1431
#    - Discriminator Train Loss: 1.4763 - Discriminator Validation Loss: 1.4218
# No improvement for 3 epoch(s).
# Epoch 12/1000
#    - Generator Train Loss: 2.0702 - Generator Validation Loss: 2.0984
#    - Discriminator Train Loss: 1.4766 - Discriminator Validation Loss: 1.4339
# No improvement for 4 epoch(s).
# Epoch 13/1000
#    - Generator Train Loss: 2.0620 - Generator Validation Loss: 2.1128
#    - Discriminator Train Loss: 1.4770 - Discriminator Validation Loss: 1.4591
# No improvement for 5 epoch(s).
# Epoch 14/1000
#    - Generator Train Loss: 2.0595 - Generator Validation Loss: 2.0774
#    - Discriminator Train Loss: 1.4774 - Discriminator Validation Loss: 1.4781
# No improvement for 6 epoch(s).
# Epoch 15/1000
#    - Generator Train Loss: 2.0643 - Generator Validation Loss: 2.0791
#    - Discriminator Train Loss: 1.4767 - Discriminator Validation Loss: 1.4878
# No improvement for 7 epoch(s).
# Epoch 16/1000
#    - Generator Train Loss: 2.0656 - Generator Validation Loss: 2.1052
#    - Discriminator Train Loss: 1.4762 - Discriminator Validation Loss: 1.4377
# No improvement for 8 epoch(s).
# Epoch 17/1000
#    - Generator Train Loss: 2.0636 - Generator Validation Loss: 2.1005
#    - Discriminator Train Loss: 1.4768 - Discriminator Validation Loss: 1.4407
# No improvement for 9 epoch(s).
# Epoch 18/1000
#    - Generator Train Loss: 2.0678 - Generator Validation Loss: 2.0855
#    - Discriminator Train Loss: 1.4762 - Discriminator Validation Loss: 1.4706
# No improvement for 10 epoch(s).
# Epoch 19/1000
#    - Generator Train Loss: 2.0670 - Generator Validation Loss: 2.0655
#    - Discriminator Train Loss: 1.4761 - Discriminator Validation Loss: 1.4597
# No improvement for 11 epoch(s).
# Epoch 20/1000
#    - Generator Train Loss: 2.0632 - Generator Validation Loss: 2.0925
#    - Discriminator Train Loss: 1.4771 - Discriminator Validation Loss: 1.4889
# No improvement for 12 epoch(s).
# Epoch 21/1000
#    - Generator Train Loss: 2.0588 - Generator Validation Loss: 2.0860
#    - Discriminator Train Loss: 1.4774 - Discriminator Validation Loss: 1.4823
# No improvement for 13 epoch(s).
# Epoch 22/1000
#    - Generator Train Loss: 2.0587 - Generator Validation Loss: 2.1063
#    - Discriminator Train Loss: 1.4769 - Discriminator Validation Loss: 1.4433
# No improvement for 14 epoch(s).
# Epoch 23/1000
#    - Generator Train Loss: 2.0605 - Generator Validation Loss: 2.0775
#    - Discriminator Train Loss: 1.4774 - Discriminator Validation Loss: 1.4813
# No improvement for 15 epoch(s).
# Epoch 24/1000
#    - Generator Train Loss: 2.0553 - Generator Validation Loss: 2.0633
#    - Discriminator Train Loss: 1.4763 - Discriminator Validation Loss: 1.4807
# No improvement for 16 epoch(s).
# Epoch 25/1000
#    - Generator Train Loss: 2.0550 - Generator Validation Loss: 2.0676
#    - Discriminator Train Loss: 1.4771 - Discriminator Validation Loss: 1.4820
# No improvement for 17 epoch(s).
# Epoch 26/1000
#    - Generator Train Loss: 2.0526 - Generator Validation Loss: 2.0840
#    - Discriminator Train Loss: 1.4762 - Discriminator Validation Loss: 1.4815
# No improvement for 18 epoch(s).
# Epoch 27/1000
#    - Generator Train Loss: 2.0586 - Generator Validation Loss: 2.0775
#    - Discriminator Train Loss: 1.4768 - Discriminator Validation Loss: 1.4760
# No improvement for 19 epoch(s).
# Epoch 28/1000
#    - Generator Train Loss: 2.0526 - Generator Validation Loss: 2.0746
#    - Discriminator Train Loss: 1.4769 - Discriminator Validation Loss: 1.4801
# No improvement for 20 epoch(s).
# Epoch 29/1000
#    - Generator Train Loss: 2.0527 - Generator Validation Loss: 2.0802
#    - Discriminator Train Loss: 1.4770 - Discriminator Validation Loss: 1.4683
# No improvement for 21 epoch(s).
# Epoch 30/1000
#    - Generator Train Loss: 2.0514 - Generator Validation Loss: 2.0611
#    - Discriminator Train Loss: 1.4765 - Discriminator Validation Loss: 1.4745
# No improvement for 22 epoch(s).
# Epoch 31/1000
#    - Generator Train Loss: 2.0496 - Generator Validation Loss: 2.0583
#    - Discriminator Train Loss: 1.4772 - Discriminator Validation Loss: 1.4795
# No improvement for 23 epoch(s).
# Epoch 32/1000
#    - Generator Train Loss: 2.0504 - Generator Validation Loss: 2.1303
#    - Discriminator Train Loss: 1.4771 - Discriminator Validation Loss: 1.4259
# No improvement for 24 epoch(s).
# Epoch 33/1000
#    - Generator Train Loss: 2.0402 - Generator Validation Loss: 2.0618
#    - Discriminator Train Loss: 1.4773 - Discriminator Validation Loss: 1.4840
# No improvement for 25 epoch(s).
# Epoch 34/1000
#    - Generator Train Loss: 2.0501 - Generator Validation Loss: 2.1086
#    - Discriminator Train Loss: 1.4764 - Discriminator Validation Loss: 1.4847
# No improvement for 26 epoch(s).
# Epoch 35/1000
#    - Generator Train Loss: 2.0424 - Generator Validation Loss: 2.1029
#    - Discriminator Train Loss: 1.4764 - Discriminator Validation Loss: 1.4344
# No improvement for 27 epoch(s).
# Epoch 36/1000
#    - Generator Train Loss: 2.0396 - Generator Validation Loss: 2.0731
#    - Discriminator Train Loss: 1.4768 - Discriminator Validation Loss: 1.4834
# No improvement for 28 epoch(s).
# Epoch 37/1000
#    - Generator Train Loss: 2.0364 - Generator Validation Loss: 2.1387
#    - Discriminator Train Loss: 1.4771 - Discriminator Validation Loss: 1.4274
# No improvement for 29 epoch(s).
# Epoch 38/1000
#    - Generator Train Loss: 2.0325 - Generator Validation Loss: 2.0490
#    - Discriminator Train Loss: 1.4770 - Discriminator Validation Loss: 1.4738
# Validation loss improved. Best model updated.
# Epoch 39/1000
#    - Generator Train Loss: 2.0343 - Generator Validation Loss: 2.0599
#    - Discriminator Train Loss: 1.4762 - Discriminator Validation Loss: 1.4689
# No improvement for 1 epoch(s).
# Epoch 40/1000
#    - Generator Train Loss: 2.0330 - Generator Validation Loss: 2.0596
#    - Discriminator Train Loss: 1.4771 - Discriminator Validation Loss: 1.4785
# No improvement for 2 epoch(s).
# Epoch 41/1000
#    - Generator Train Loss: 2.0363 - Generator Validation Loss: 2.0488
#    - Discriminator Train Loss: 1.4765 - Discriminator Validation Loss: 1.4797
# Validation loss improved. Best model updated.
# Epoch 42/1000
#    - Generator Train Loss: 2.0322 - Generator Validation Loss: 2.0557
#    - Discriminator Train Loss: 1.4761 - Discriminator Validation Loss: 1.4798
# No improvement for 1 epoch(s).
# Epoch 43/1000
#    - Generator Train Loss: 2.0252 - Generator Validation Loss: 2.0409
#    - Discriminator Train Loss: 1.4778 - Discriminator Validation Loss: 1.4841
# Validation loss improved. Best model updated.
# Epoch 44/1000
#    - Generator Train Loss: 2.0304 - Generator Validation Loss: 2.1254
#    - Discriminator Train Loss: 1.4760 - Discriminator Validation Loss: 1.4250
# No improvement for 1 epoch(s).
# Epoch 45/1000
#    - Generator Train Loss: 2.0253 - Generator Validation Loss: 2.0305
#    - Discriminator Train Loss: 1.4775 - Discriminator Validation Loss: 1.4511
# Validation loss improved. Best model updated.
# Epoch 46/1000
#    - Generator Train Loss: 2.0293 - Generator Validation Loss: 2.0518
#    - Discriminator Train Loss: 1.4767 - Discriminator Validation Loss: 1.4835
# No improvement for 1 epoch(s).
# Epoch 47/1000
#    - Generator Train Loss: 2.0290 - Generator Validation Loss: 2.0448
#    - Discriminator Train Loss: 1.4772 - Discriminator Validation Loss: 1.4587
# No improvement for 2 epoch(s).
# Epoch 48/1000
#    - Generator Train Loss: 2.0262 - Generator Validation Loss: 2.0558
#    - Discriminator Train Loss: 1.4760 - Discriminator Validation Loss: 1.4795
# No improvement for 3 epoch(s).
# Epoch 49/1000
#    - Generator Train Loss: 2.0282 - Generator Validation Loss: 2.0631
#    - Discriminator Train Loss: 1.4769 - Discriminator Validation Loss: 1.4776
# No improvement for 4 epoch(s).
# Epoch 50/1000
#    - Generator Train Loss: 2.0249 - Generator Validation Loss: 2.0291
#    - Discriminator Train Loss: 1.4770 - Discriminator Validation Loss: 1.4830
# Validation loss improved. Best model updated.
# Epoch 51/1000
#    - Generator Train Loss: 2.2055 - Generator Validation Loss: 2.2614
#    - Discriminator Train Loss: 1.4016 - Discriminator Validation Loss: 1.3901
# Validation loss improved. Best model updated.
# Epoch 52/1000
#    - Generator Train Loss: 2.1931 - Generator Validation Loss: 2.2503
#    - Discriminator Train Loss: 1.3904 - Discriminator Validation Loss: 1.3874
# Validation loss improved. Best model updated.
# Epoch 53/1000
#    - Generator Train Loss: 2.1891 - Generator Validation Loss: 2.2906
#    - Discriminator Train Loss: 1.3901 - Discriminator Validation Loss: 1.3871
# No improvement for 1 epoch(s).
# Epoch 54/1000
#    - Generator Train Loss: 2.1839 - Generator Validation Loss: 2.4185
#    - Discriminator Train Loss: 1.3884 - Discriminator Validation Loss: 1.3867
# No improvement for 2 epoch(s).
# Epoch 55/1000
#    - Generator Train Loss: 2.1880 - Generator Validation Loss: 2.3673
#    - Discriminator Train Loss: 1.3877 - Discriminator Validation Loss: 1.3866
# No improvement for 3 epoch(s).
# Epoch 56/1000
#    - Generator Train Loss: 2.1846 - Generator Validation Loss: 2.2543
#    - Discriminator Train Loss: 1.3876 - Discriminator Validation Loss: 1.3887
# No improvement for 4 epoch(s).
# Epoch 57/1000
#    - Generator Train Loss: 2.1825 - Generator Validation Loss: 2.2299
#    - Discriminator Train Loss: 1.3871 - Discriminator Validation Loss: 1.3866
# Validation loss improved. Best model updated.
# Epoch 58/1000
#    - Generator Train Loss: 2.1865 - Generator Validation Loss: 2.2439
#    - Discriminator Train Loss: 1.3872 - Discriminator Validation Loss: 1.3866
# No improvement for 1 epoch(s).
# Epoch 59/1000
#    - Generator Train Loss: 2.1882 - Generator Validation Loss: 2.2611
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3865
# No improvement for 2 epoch(s).
# Epoch 60/1000
#    - Generator Train Loss: 2.1873 - Generator Validation Loss: 2.2605
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3864
# No improvement for 3 epoch(s).
# Epoch 61/1000
#    - Generator Train Loss: 2.1859 - Generator Validation Loss: 2.2417
#    - Discriminator Train Loss: 1.3869 - Discriminator Validation Loss: 1.3864
# No improvement for 4 epoch(s).
# Epoch 62/1000
#    - Generator Train Loss: 2.1853 - Generator Validation Loss: 2.3865
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3864
# No improvement for 5 epoch(s).
# Epoch 63/1000
#    - Generator Train Loss: 2.1829 - Generator Validation Loss: 2.2590
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3872
# No improvement for 6 epoch(s).
# Epoch 64/1000
#    - Generator Train Loss: 2.1870 - Generator Validation Loss: 2.2114
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3929
# Validation loss improved. Best model updated.
# Epoch 65/1000
#    - Generator Train Loss: 2.1866 - Generator Validation Loss: 2.2525
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3867
# No improvement for 1 epoch(s).
# Epoch 66/1000
#    - Generator Train Loss: 2.1815 - Generator Validation Loss: 2.3112
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3875
# No improvement for 2 epoch(s).
# Epoch 67/1000
#    - Generator Train Loss: 2.1872 - Generator Validation Loss: 2.2388
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3864
# No improvement for 3 epoch(s).
# Epoch 68/1000
#    - Generator Train Loss: 2.1841 - Generator Validation Loss: 2.2432
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3865
# No improvement for 4 epoch(s).
# Epoch 69/1000
#    - Generator Train Loss: 2.1810 - Generator Validation Loss: 2.2360
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3863
# No improvement for 5 epoch(s).
# Epoch 70/1000
#    - Generator Train Loss: 2.1825 - Generator Validation Loss: 2.2225
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3864
# No improvement for 6 epoch(s).
# Epoch 71/1000
#    - Generator Train Loss: 2.1855 - Generator Validation Loss: 2.2599
#    - Discriminator Train Loss: 1.3867 - Discriminator Validation Loss: 1.3867
# No improvement for 7 epoch(s).
# Epoch 72/1000
#    - Generator Train Loss: 2.1847 - Generator Validation Loss: 2.2308
#    - Discriminator Train Loss: 1.3869 - Discriminator Validation Loss: 1.3864
# No improvement for 8 epoch(s).
# Epoch 73/1000
#    - Generator Train Loss: 2.1836 - Generator Validation Loss: 2.2762
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3865
# No improvement for 9 epoch(s).
# Epoch 74/1000
#    - Generator Train Loss: 2.1854 - Generator Validation Loss: 2.3256
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3881
# No improvement for 10 epoch(s).
# Epoch 75/1000
#    - Generator Train Loss: 2.1810 - Generator Validation Loss: 2.2630
#    - Discriminator Train Loss: 1.3868 - Discriminator Validation Loss: 1.3862
# No improvement for 11 epoch(s).
# Epoch 76/1000
#    - Generator Train Loss: 2.1866 - Generator Validation Loss: 2.2692
#    - Discriminator Train Loss: 1.3862 - Discriminator Validation Loss: 1.3864
# No improvement for 12 epoch(s).
# Epoch 77/1000
#    - Generator Train Loss: 2.1789 - Generator Validation Loss: 2.2239
#    - Discriminator Train Loss: 1.3865 - Discriminator Validation Loss: 1.3856
# No improvement for 13 epoch(s).
# Epoch 78/1000
#    - Generator Train Loss: 2.1915 - Generator Validation Loss: 2.2439
#    - Discriminator Train Loss: 1.3863 - Discriminator Validation Loss: 1.3862
# No improvement for 14 epoch(s).
# Epoch 79/1000
#    - Generator Train Loss: 2.1870 - Generator Validation Loss: 2.2145
#    - Discriminator Train Loss: 1.3856 - Discriminator Validation Loss: 1.3893
# No improvement for 15 epoch(s).
# Epoch 80/1000
#    - Generator Train Loss: 2.1904 - Generator Validation Loss: 2.2784
#    - Discriminator Train Loss: 1.3855 - Discriminator Validation Loss: 1.3876
# No improvement for 16 epoch(s).
# Epoch 81/1000
#    - Generator Train Loss: 2.1923 - Generator Validation Loss: 2.3048
#    - Discriminator Train Loss: 1.3855 - Discriminator Validation Loss: 1.3870
# No improvement for 17 epoch(s).
# Epoch 82/1000
#    - Generator Train Loss: 2.1976 - Generator Validation Loss: 2.2498
#    - Discriminator Train Loss: 1.3855 - Discriminator Validation Loss: 1.3857
# No improvement for 18 epoch(s).
# Epoch 83/1000
#    - Generator Train Loss: 2.1988 - Generator Validation Loss: 2.2368
#    - Discriminator Train Loss: 1.3847 - Discriminator Validation Loss: 1.3939
# No improvement for 19 epoch(s).
# Epoch 84/1000
#    - Generator Train Loss: 2.1958 - Generator Validation Loss: 2.3582
#    - Discriminator Train Loss: 1.3859 - Discriminator Validation Loss: 1.3906
# No improvement for 20 epoch(s).
# Epoch 85/1000
#    - Generator Train Loss: 2.2072 - Generator Validation Loss: 2.1517
#    - Discriminator Train Loss: 1.3847 - Discriminator Validation Loss: 1.3937
# Validation loss improved. Best model updated.
# Epoch 86/1000
#    - Generator Train Loss: 2.2030 - Generator Validation Loss: 1.9698
#    - Discriminator Train Loss: 1.3844 - Discriminator Validation Loss: 1.4189
# Validation loss improved. Best model updated.
# Epoch 87/1000
#    - Generator Train Loss: 2.2097 - Generator Validation Loss: 2.2167
#    - Discriminator Train Loss: 1.3844 - Discriminator Validation Loss: 1.3839
# No improvement for 1 epoch(s).
# Epoch 88/1000
#    - Generator Train Loss: 2.2107 - Generator Validation Loss: 2.2380
#    - Discriminator Train Loss: 1.3839 - Discriminator Validation Loss: 1.3884
# No improvement for 2 epoch(s).
# Epoch 89/1000
#    - Generator Train Loss: 2.2142 - Generator Validation Loss: 2.2455
#    - Discriminator Train Loss: 1.3806 - Discriminator Validation Loss: 1.3877
# No improvement for 3 epoch(s).
# Epoch 90/1000
#    - Generator Train Loss: 2.1980 - Generator Validation Loss: 2.2331
#    - Discriminator Train Loss: 1.3826 - Discriminator Validation Loss: 1.3873
# No improvement for 4 epoch(s).
# Epoch 91/1000
#    - Generator Train Loss: 2.2144 - Generator Validation Loss: 2.2956
#    - Discriminator Train Loss: 1.3813 - Discriminator Validation Loss: 1.3876
# No improvement for 5 epoch(s).
# Epoch 92/1000
#    - Generator Train Loss: 2.2165 - Generator Validation Loss: 2.1999
#    - Discriminator Train Loss: 1.3774 - Discriminator Validation Loss: 1.3887
# No improvement for 6 epoch(s).
# Epoch 93/1000
#    - Generator Train Loss: 2.2055 - Generator Validation Loss: 2.2868
#    - Discriminator Train Loss: 1.3818 - Discriminator Validation Loss: 1.3817
# No improvement for 7 epoch(s).
# Epoch 94/1000
#    - Generator Train Loss: 2.2086 - Generator Validation Loss: 2.2972
#    - Discriminator Train Loss: 1.3804 - Discriminator Validation Loss: 1.3873
# No improvement for 8 epoch(s).
# Epoch 95/1000
#    - Generator Train Loss: 2.2226 - Generator Validation Loss: 2.1286
#    - Discriminator Train Loss: 1.3823 - Discriminator Validation Loss: 1.3962
# No improvement for 9 epoch(s).
# Epoch 96/1000
#    - Generator Train Loss: 2.2516 - Generator Validation Loss: 2.3169
#    - Discriminator Train Loss: 1.3740 - Discriminator Validation Loss: 1.3947
# No improvement for 10 epoch(s).
# Epoch 97/1000
#    - Generator Train Loss: 2.2820 - Generator Validation Loss: 2.2671
#    - Discriminator Train Loss: 1.3672 - Discriminator Validation Loss: 1.3912
# No improvement for 11 epoch(s).
# Epoch 98/1000
#    - Generator Train Loss: 2.2718 - Generator Validation Loss: 2.2695
#    - Discriminator Train Loss: 1.3685 - Discriminator Validation Loss: 1.3893
# No improvement for 12 epoch(s).
# Epoch 99/1000
#    - Generator Train Loss: 2.2301 - Generator Validation Loss: 2.3156
#    - Discriminator Train Loss: 1.3748 - Discriminator Validation Loss: 1.3916
# No improvement for 13 epoch(s).
# Epoch 100/1000
#    - Generator Train Loss: 2.2859 - Generator Validation Loss: 2.2002
#    - Discriminator Train Loss: 1.3641 - Discriminator Validation Loss: 1.3869
# No improvement for 14 epoch(s).
# Epoch 101/1000
#    - Generator Train Loss: 2.1938 - Generator Validation Loss: 2.3906
#    - Discriminator Train Loss: 1.3835 - Discriminator Validation Loss: 1.3840
# No improvement for 15 epoch(s).
# Epoch 102/1000
#    - Generator Train Loss: 2.2380 - Generator Validation Loss: 2.2390
#    - Discriminator Train Loss: 1.3721 - Discriminator Validation Loss: 1.3840
# No improvement for 16 epoch(s).
# Epoch 103/1000
#    - Generator Train Loss: 2.2992 - Generator Validation Loss: 2.2946
#    - Discriminator Train Loss: 1.3710 - Discriminator Validation Loss: 1.3877
# No improvement for 17 epoch(s).
# Epoch 104/1000
#    - Generator Train Loss: 2.2273 - Generator Validation Loss: 2.2006
#    - Discriminator Train Loss: 1.3847 - Discriminator Validation Loss: 1.3892
# No improvement for 18 epoch(s).
# Epoch 105/1000
#    - Generator Train Loss: 2.2972 - Generator Validation Loss: 2.2143
#    - Discriminator Train Loss: 1.3619 - Discriminator Validation Loss: 1.3869
# No improvement for 19 epoch(s).
# Epoch 106/1000
#    - Generator Train Loss: 2.2198 - Generator Validation Loss: 3.0385
#    - Discriminator Train Loss: 1.3797 - Discriminator Validation Loss: 1.5365
# No improvement for 20 epoch(s).
# Epoch 107/1000
#    - Generator Train Loss: 2.3570 - Generator Validation Loss: 2.2361
#    - Discriminator Train Loss: 1.3459 - Discriminator Validation Loss: 1.3974
# No improvement for 21 epoch(s).
# Epoch 108/1000
#    - Generator Train Loss: 2.2531 - Generator Validation Loss: 2.1748
#    - Discriminator Train Loss: 1.3768 - Discriminator Validation Loss: 1.4107
# No improvement for 22 epoch(s).
# Epoch 109/1000
#    - Generator Train Loss: 2.3698 - Generator Validation Loss: 2.3653
#    - Discriminator Train Loss: 1.3434 - Discriminator Validation Loss: 1.4849
# No improvement for 23 epoch(s).
# Epoch 110/1000
#    - Generator Train Loss: 2.4763 - Generator Validation Loss: 2.6594
#    - Discriminator Train Loss: 1.3196 - Discriminator Validation Loss: 1.4198
# No improvement for 24 epoch(s).
# Epoch 111/1000
#    - Generator Train Loss: 2.2428 - Generator Validation Loss: 2.2886
#    - Discriminator Train Loss: 1.3715 - Discriminator Validation Loss: 1.3794
# No improvement for 25 epoch(s).
# Epoch 112/1000
#    - Generator Train Loss: 2.2063 - Generator Validation Loss: 2.2574
#    - Discriminator Train Loss: 1.3786 - Discriminator Validation Loss: 1.3943
# No improvement for 26 epoch(s).
# Epoch 113/1000
#    - Generator Train Loss: 2.3008 - Generator Validation Loss: 2.2994
#    - Discriminator Train Loss: 1.3655 - Discriminator Validation Loss: 1.3872
# No improvement for 27 epoch(s).
# Epoch 114/1000
#    - Generator Train Loss: 2.3387 - Generator Validation Loss: 2.4689
#    - Discriminator Train Loss: 1.3595 - Discriminator Validation Loss: 1.4229
# No improvement for 28 epoch(s).
# Epoch 115/1000
#    - Generator Train Loss: 2.6922 - Generator Validation Loss: 2.3711
#    - Discriminator Train Loss: 1.2481 - Discriminator Validation Loss: 1.4274
# No improvement for 29 epoch(s).
# Epoch 116/1000
#    - Generator Train Loss: 2.6847 - Generator Validation Loss: 2.1388
#    - Discriminator Train Loss: 1.2526 - Discriminator Validation Loss: 1.4070
# No improvement for 30 epoch(s).
# Epoch 117/1000
#    - Generator Train Loss: 2.5848 - Generator Validation Loss: 2.8003
#    - Discriminator Train Loss: 1.3130 - Discriminator Validation Loss: 1.4871
# No improvement for 31 epoch(s).
# Epoch 118/1000
#    - Generator Train Loss: 2.3378 - Generator Validation Loss: 2.3370
#    - Discriminator Train Loss: 1.3580 - Discriminator Validation Loss: 1.3888
# No improvement for 32 epoch(s).
# Epoch 119/1000
#    - Generator Train Loss: 2.5991 - Generator Validation Loss: 2.3200
#    - Discriminator Train Loss: 1.2944 - Discriminator Validation Loss: 1.3957
# No improvement for 33 epoch(s).
# Epoch 120/1000
#    - Generator Train Loss: 2.6267 - Generator Validation Loss: 2.3666
#    - Discriminator Train Loss: 1.2661 - Discriminator Validation Loss: 1.3524
# No improvement for 34 epoch(s).
# Epoch 121/1000
#    - Generator Train Loss: 2.7782 - Generator Validation Loss: 1.9022
#    - Discriminator Train Loss: 1.2154 - Discriminator Validation Loss: 1.4711
# Validation loss improved. Best model updated.
# Epoch 122/1000
#    - Generator Train Loss: 2.5854 - Generator Validation Loss: 2.2779
#    - Discriminator Train Loss: 1.2546 - Discriminator Validation Loss: 1.3876
# No improvement for 1 epoch(s).
# Epoch 123/1000
#    - Generator Train Loss: 2.2661 - Generator Validation Loss: 2.2521
#    - Discriminator Train Loss: 1.3875 - Discriminator Validation Loss: 1.3874
# No improvement for 2 epoch(s).
# Epoch 124/1000
#    - Generator Train Loss: 2.2692 - Generator Validation Loss: 2.2020
#    - Discriminator Train Loss: 1.3818 - Discriminator Validation Loss: 1.3901
# No improvement for 3 epoch(s).
# Epoch 125/1000
#    - Generator Train Loss: 2.3065 - Generator Validation Loss: 2.3145
#    - Discriminator Train Loss: 1.3658 - Discriminator Validation Loss: 1.3941
# No improvement for 4 epoch(s).
# Epoch 126/1000
#    - Generator Train Loss: 2.3533 - Generator Validation Loss: 2.5100
#    - Discriminator Train Loss: 1.3260 - Discriminator Validation Loss: 1.4095
# No improvement for 5 epoch(s).
# Epoch 127/1000
#    - Generator Train Loss: 2.4509 - Generator Validation Loss: 2.2391
#    - Discriminator Train Loss: 1.2843 - Discriminator Validation Loss: 1.4205
# No improvement for 6 epoch(s).
# Epoch 128/1000
#    - Generator Train Loss: 2.5370 - Generator Validation Loss: 2.2311
#    - Discriminator Train Loss: 1.2670 - Discriminator Validation Loss: 1.4261
# No improvement for 7 epoch(s).
# Epoch 129/1000
#    - Generator Train Loss: 2.5660 - Generator Validation Loss: 2.2637
#    - Discriminator Train Loss: 1.2881 - Discriminator Validation Loss: 1.3891
# No improvement for 8 epoch(s).
# Epoch 130/1000
#    - Generator Train Loss: 2.4840 - Generator Validation Loss: 2.1760
#    - Discriminator Train Loss: 1.3318 - Discriminator Validation Loss: 1.3833
# No improvement for 9 epoch(s).
# Epoch 131/1000
#    - Generator Train Loss: 2.2446 - Generator Validation Loss: 2.2578
#    - Discriminator Train Loss: 1.3866 - Discriminator Validation Loss: 1.3950
# No improvement for 10 epoch(s).
# Epoch 132/1000
#    - Generator Train Loss: 2.4068 - Generator Validation Loss: 2.2272
#    - Discriminator Train Loss: 1.3581 - Discriminator Validation Loss: 1.3935
# No improvement for 11 epoch(s).
# Epoch 133/1000
#    - Generator Train Loss: 2.2634 - Generator Validation Loss: 2.2398
#    - Discriminator Train Loss: 1.3746 - Discriminator Validation Loss: 1.3888
# No improvement for 12 epoch(s).
# Epoch 134/1000
#    - Generator Train Loss: 2.5773 - Generator Validation Loss: 2.2359
#    - Discriminator Train Loss: 1.2937 - Discriminator Validation Loss: 1.4023
# No improvement for 13 epoch(s).
# Epoch 135/1000
#    - Generator Train Loss: 2.6068 - Generator Validation Loss: 3.2867
#    - Discriminator Train Loss: 1.2696 - Discriminator Validation Loss: 1.5163
# No improvement for 14 epoch(s).
# Epoch 136/1000
#    - Generator Train Loss: 3.2234 - Generator Validation Loss: 2.3970
#    - Discriminator Train Loss: 1.1246 - Discriminator Validation Loss: 1.4201
# No improvement for 15 epoch(s).
# Epoch 137/1000
#    - Generator Train Loss: 3.4081 - Generator Validation Loss: 2.0115
#    - Discriminator Train Loss: 1.0493 - Discriminator Validation Loss: 1.5060
# No improvement for 16 epoch(s).
# Epoch 138/1000
#    - Generator Train Loss: 3.6785 - Generator Validation Loss: 2.0665
#    - Discriminator Train Loss: 0.9679 - Discriminator Validation Loss: 1.4399
# No improvement for 17 epoch(s).
# Epoch 139/1000
#    - Generator Train Loss: 3.8627 - Generator Validation Loss: 2.4227
#    - Discriminator Train Loss: 0.9497 - Discriminator Validation Loss: 1.3911
# No improvement for 18 epoch(s).
# Epoch 140/1000
#    - Generator Train Loss: 3.3162 - Generator Validation Loss: 2.8127
#    - Discriminator Train Loss: 1.0452 - Discriminator Validation Loss: 1.7470
# No improvement for 19 epoch(s).
# Epoch 141/1000
#    - Generator Train Loss: 3.4909 - Generator Validation Loss: 2.2559
#    - Discriminator Train Loss: 1.0347 - Discriminator Validation Loss: 1.4010
# No improvement for 20 epoch(s).
# Epoch 142/1000
#    - Generator Train Loss: 2.4408 - Generator Validation Loss: 2.5418
#    - Discriminator Train Loss: 1.3364 - Discriminator Validation Loss: 1.4395
# No improvement for 21 epoch(s).
# Epoch 143/1000
#    - Generator Train Loss: 3.0870 - Generator Validation Loss: 2.8482
#    - Discriminator Train Loss: 1.1896 - Discriminator Validation Loss: 1.4624
# No improvement for 22 epoch(s).
# Epoch 144/1000
#    - Generator Train Loss: 4.2471 - Generator Validation Loss: 1.2872
#    - Discriminator Train Loss: 0.7733 - Discriminator Validation Loss: 2.0348
# Validation loss improved. Best model updated.
# Epoch 145/1000
#    - Generator Train Loss: 2.9147 - Generator Validation Loss: 2.2334
#    - Discriminator Train Loss: 1.2302 - Discriminator Validation Loss: 1.4184
# No improvement for 1 epoch(s).
# Epoch 146/1000
#    - Generator Train Loss: 2.2949 - Generator Validation Loss: 2.0056
#    - Discriminator Train Loss: 1.3927 - Discriminator Validation Loss: 1.4228
# No improvement for 2 epoch(s).
# Epoch 147/1000
#    - Generator Train Loss: 3.4973 - Generator Validation Loss: 2.0587
#    - Discriminator Train Loss: 1.0636 - Discriminator Validation Loss: 1.4650
# No improvement for 3 epoch(s).
# Epoch 148/1000
#    - Generator Train Loss: 2.7831 - Generator Validation Loss: 2.2695
#    - Discriminator Train Loss: 1.2901 - Discriminator Validation Loss: 1.3855
# No improvement for 4 epoch(s).
# Epoch 149/1000
#    - Generator Train Loss: 3.7609 - Generator Validation Loss: 2.3539
#    - Discriminator Train Loss: 1.0144 - Discriminator Validation Loss: 1.4882
# No improvement for 5 epoch(s).
# Epoch 150/1000
#    - Generator Train Loss: 3.2612 - Generator Validation Loss: 2.4460
#    - Discriminator Train Loss: 1.0994 - Discriminator Validation Loss: 1.6784
# No improvement for 6 epoch(s).
# Epoch 151/1000
#    - Generator Train Loss: 4.3982 - Generator Validation Loss: 2.0286
#    - Discriminator Train Loss: 0.7371 - Discriminator Validation Loss: 1.4111
# No improvement for 7 epoch(s).
# Epoch 152/1000
#    - Generator Train Loss: 4.8931 - Generator Validation Loss: 1.4282
#    - Discriminator Train Loss: 0.6429 - Discriminator Validation Loss: 1.8038
# No improvement for 8 epoch(s).
# Epoch 153/1000
#    - Generator Train Loss: 4.9857 - Generator Validation Loss: 1.7321
#    - Discriminator Train Loss: 0.6185 - Discriminator Validation Loss: 1.6340
# No improvement for 9 epoch(s).
# Epoch 154/1000
#    - Generator Train Loss: 4.7351 - Generator Validation Loss: 2.0633
#    - Discriminator Train Loss: 0.7666 - Discriminator Validation Loss: 1.4076
# No improvement for 10 epoch(s).
# Epoch 155/1000
#    - Generator Train Loss: 3.2183 - Generator Validation Loss: 2.2124
#    - Discriminator Train Loss: 1.1407 - Discriminator Validation Loss: 1.4028
# No improvement for 11 epoch(s).
# Epoch 156/1000
#    - Generator Train Loss: 2.3351 - Generator Validation Loss: 2.2106
#    - Discriminator Train Loss: 1.3690 - Discriminator Validation Loss: 1.3930
# No improvement for 12 epoch(s).
# Epoch 157/1000
#    - Generator Train Loss: 2.2992 - Generator Validation Loss: 2.2848
#    - Discriminator Train Loss: 1.4022 - Discriminator Validation Loss: 1.3901
# No improvement for 13 epoch(s).
# Epoch 158/1000
#    - Generator Train Loss: 2.2612 - Generator Validation Loss: 2.2936
#    - Discriminator Train Loss: 1.3825 - Discriminator Validation Loss: 1.3871
# No improvement for 14 epoch(s).
# Epoch 159/1000
#    - Generator Train Loss: 3.0066 - Generator Validation Loss: 1.6897
#    - Discriminator Train Loss: 1.2104 - Discriminator Validation Loss: 1.6322
# No improvement for 15 epoch(s).
# Epoch 160/1000
#    - Generator Train Loss: 4.8043 - Generator Validation Loss: 1.8620
#    - Discriminator Train Loss: 0.6794 - Discriminator Validation Loss: 1.5804
# No improvement for 16 epoch(s).
# Epoch 161/1000
#    - Generator Train Loss: 4.3471 - Generator Validation Loss: 1.6125
#    - Discriminator Train Loss: 0.8875 - Discriminator Validation Loss: 1.6701
# No improvement for 17 epoch(s).
# Epoch 162/1000
#    - Generator Train Loss: 4.5676 - Generator Validation Loss: 2.2585
#    - Discriminator Train Loss: 0.8074 - Discriminator Validation Loss: 1.4864
# No improvement for 18 epoch(s).
# Epoch 163/1000
#    - Generator Train Loss: 2.3806 - Generator Validation Loss: 2.2940
#    - Discriminator Train Loss: 1.3808 - Discriminator Validation Loss: 1.3975
# No improvement for 19 epoch(s).
# Epoch 164/1000
#    - Generator Train Loss: 3.3982 - Generator Validation Loss: 1.3505
#    - Discriminator Train Loss: 1.0213 - Discriminator Validation Loss: 1.9881
# No improvement for 20 epoch(s).
# Epoch 165/1000
#    - Generator Train Loss: 5.0029 - Generator Validation Loss: 2.3627
#    - Discriminator Train Loss: 0.6461 - Discriminator Validation Loss: 1.3834
# No improvement for 21 epoch(s).
# Epoch 166/1000
#    - Generator Train Loss: 4.7406 - Generator Validation Loss: 2.4361
#    - Discriminator Train Loss: 0.7824 - Discriminator Validation Loss: 1.3992
# No improvement for 22 epoch(s).
# Epoch 167/1000
#    - Generator Train Loss: 3.2365 - Generator Validation Loss: 2.3038
#    - Discriminator Train Loss: 1.1275 - Discriminator Validation Loss: 1.3872
# No improvement for 23 epoch(s).
# Epoch 168/1000
#    - Generator Train Loss: 2.7722 - Generator Validation Loss: 2.0053
#    - Discriminator Train Loss: 1.2796 - Discriminator Validation Loss: 1.6842
# No improvement for 24 epoch(s).
# Epoch 169/1000
#    - Generator Train Loss: 5.6079 - Generator Validation Loss: 2.1271
#    - Discriminator Train Loss: 0.5285 - Discriminator Validation Loss: 1.3064
# No improvement for 25 epoch(s).
# Epoch 170/1000
#    - Generator Train Loss: 4.1328 - Generator Validation Loss: 1.5932
#    - Discriminator Train Loss: 0.9918 - Discriminator Validation Loss: 1.6302
# No improvement for 26 epoch(s).
# Epoch 171/1000
#    - Generator Train Loss: 3.9250 - Generator Validation Loss: 1.8836
#    - Discriminator Train Loss: 1.0294 - Discriminator Validation Loss: 1.5341
# No improvement for 27 epoch(s).
# Epoch 172/1000
#    - Generator Train Loss: 4.5910 - Generator Validation Loss: 1.0265
#    - Discriminator Train Loss: 0.7327 - Discriminator Validation Loss: 3.3764
# Validation loss improved. Best model updated.
# Epoch 173/1000
#    - Generator Train Loss: 5.1252 - Generator Validation Loss: 1.9692
#    - Discriminator Train Loss: 0.6548 - Discriminator Validation Loss: 1.4955
# No improvement for 1 epoch(s).
# Epoch 174/1000
#    - Generator Train Loss: 5.0139 - Generator Validation Loss: 1.5426
#    - Discriminator Train Loss: 0.6424 - Discriminator Validation Loss: 1.9758
# No improvement for 2 epoch(s).
# Epoch 175/1000
#    - Generator Train Loss: 5.0019 - Generator Validation Loss: 1.0542
#    - Discriminator Train Loss: 0.6674 - Discriminator Validation Loss: 2.9922
# No improvement for 3 epoch(s).
# Epoch 176/1000
#    - Generator Train Loss: 5.1686 - Generator Validation Loss: 1.1345
#    - Discriminator Train Loss: 0.7084 - Discriminator Validation Loss: 2.6565
# No improvement for 4 epoch(s).
# Epoch 177/1000
#    - Generator Train Loss: 5.1826 - Generator Validation Loss: 1.7144
#    - Discriminator Train Loss: 0.6464 - Discriminator Validation Loss: 1.6116
# No improvement for 5 epoch(s).
# Epoch 178/1000
#    - Generator Train Loss: 4.8378 - Generator Validation Loss: 1.1996
#    - Discriminator Train Loss: 0.7063 - Discriminator Validation Loss: 2.3599
# No improvement for 6 epoch(s).
# Epoch 179/1000
#    - Generator Train Loss: 5.5150 - Generator Validation Loss: 3.1464
#    - Discriminator Train Loss: 0.6430 - Discriminator Validation Loss: 1.3024
# No improvement for 7 epoch(s).
# Epoch 180/1000
#    - Generator Train Loss: 5.2674 - Generator Validation Loss: 1.1825
#    - Discriminator Train Loss: 0.6186 - Discriminator Validation Loss: 2.3167
# No improvement for 8 epoch(s).
# Epoch 181/1000
#    - Generator Train Loss: 5.5390 - Generator Validation Loss: 1.8762
#    - Discriminator Train Loss: 0.6781 - Discriminator Validation Loss: 1.4794
# No improvement for 9 epoch(s).
# Epoch 182/1000
#    - Generator Train Loss: 2.5511 - Generator Validation Loss: 2.0709
#    - Discriminator Train Loss: 1.2814 - Discriminator Validation Loss: 1.4811
# No improvement for 10 epoch(s).
# Epoch 183/1000
#    - Generator Train Loss: 5.0902 - Generator Validation Loss: 1.3132
#    - Discriminator Train Loss: 0.6801 - Discriminator Validation Loss: 2.2121
# No improvement for 11 epoch(s).
# Epoch 184/1000
#    - Generator Train Loss: 5.4718 - Generator Validation Loss: 1.7833
#    - Discriminator Train Loss: 0.5508 - Discriminator Validation Loss: 1.7369
# No improvement for 12 epoch(s).
# Epoch 185/1000
#    - Generator Train Loss: 5.6908 - Generator Validation Loss: 1.3847
#    - Discriminator Train Loss: 0.4974 - Discriminator Validation Loss: 1.8669
# No improvement for 13 epoch(s).
# Epoch 186/1000
#    - Generator Train Loss: 5.4709 - Generator Validation Loss: 2.5899
#    - Discriminator Train Loss: 0.6706 - Discriminator Validation Loss: 1.1544
# No improvement for 14 epoch(s).
# Epoch 187/1000
#    - Generator Train Loss: 5.0029 - Generator Validation Loss: 1.4855
#    - Discriminator Train Loss: 0.7158 - Discriminator Validation Loss: 1.8692
# No improvement for 15 epoch(s).
# Epoch 188/1000
#    - Generator Train Loss: 4.6052 - Generator Validation Loss: 1.5786
#    - Discriminator Train Loss: 0.8415 - Discriminator Validation Loss: 1.6760
# No improvement for 16 epoch(s).
# Epoch 189/1000
#    - Generator Train Loss: 3.3538 - Generator Validation Loss: 2.5256
#    - Discriminator Train Loss: 1.0836 - Discriminator Validation Loss: 1.5041
# No improvement for 17 epoch(s).
# Epoch 190/1000
#    - Generator Train Loss: 4.5170 - Generator Validation Loss: 1.2575
#    - Discriminator Train Loss: 0.7471 - Discriminator Validation Loss: 2.1421
# No improvement for 18 epoch(s).
# Epoch 191/1000
#    - Generator Train Loss: 5.7225 - Generator Validation Loss: 1.8416
#    - Discriminator Train Loss: 0.5551 - Discriminator Validation Loss: 1.4942
# No improvement for 19 epoch(s).
# Epoch 192/1000
#    - Generator Train Loss: 5.0339 - Generator Validation Loss: 1.6170
#    - Discriminator Train Loss: 0.6813 - Discriminator Validation Loss: 1.6601
# No improvement for 20 epoch(s).
# Epoch 193/1000
#    - Generator Train Loss: 5.2884 - Generator Validation Loss: 1.8005
#    - Discriminator Train Loss: 0.6492 - Discriminator Validation Loss: 1.5538
# No improvement for 21 epoch(s).
# Epoch 194/1000
#    - Generator Train Loss: 5.1640 - Generator Validation Loss: 2.8568
#    - Discriminator Train Loss: 0.6793 - Discriminator Validation Loss: 1.0746
# No improvement for 22 epoch(s).
# Epoch 195/1000
#    - Generator Train Loss: 5.0264 - Generator Validation Loss: 2.2090
#    - Discriminator Train Loss: 0.6907 - Discriminator Validation Loss: 1.4000
# No improvement for 23 epoch(s).
# Epoch 196/1000
#    - Generator Train Loss: 3.7579 - Generator Validation Loss: 1.3773
#    - Discriminator Train Loss: 0.9767 - Discriminator Validation Loss: 2.0542
# No improvement for 24 epoch(s).
# Epoch 197/1000
#    - Generator Train Loss: 5.5208 - Generator Validation Loss: 1.4267
#    - Discriminator Train Loss: 0.5497 - Discriminator Validation Loss: 1.7883
# No improvement for 25 epoch(s).
# Epoch 198/1000
#    - Generator Train Loss: 6.0596 - Generator Validation Loss: 1.1670
#    - Discriminator Train Loss: 0.5407 - Discriminator Validation Loss: 2.4014
# No improvement for 26 epoch(s).
# Epoch 199/1000
#    - Generator Train Loss: 5.7383 - Generator Validation Loss: 1.3049
#    - Discriminator Train Loss: 0.4804 - Discriminator Validation Loss: 1.9706
# No improvement for 27 epoch(s).
# Epoch 200/1000
#    - Generator Train Loss: 5.9481 - Generator Validation Loss: 0.9589
#    - Discriminator Train Loss: 0.5197 - Discriminator Validation Loss: 4.4171
# Validation loss improved. Best model updated.
# Epoch 201/1000
#    - Generator Train Loss: 5.6091 - Generator Validation Loss: 1.0186
#    - Discriminator Train Loss: 0.5884 - Discriminator Validation Loss: 3.3374
# No improvement for 1 epoch(s).
# Epoch 202/1000
#    - Generator Train Loss: 5.6229 - Generator Validation Loss: 0.9940
#    - Discriminator Train Loss: 0.5286 - Discriminator Validation Loss: 3.9026
# No improvement for 2 epoch(s).
# Epoch 203/1000
#    - Generator Train Loss: 5.4848 - Generator Validation Loss: 1.7553
#    - Discriminator Train Loss: 0.7237 - Discriminator Validation Loss: 1.5760
# No improvement for 3 epoch(s).
# Epoch 204/1000
#    - Generator Train Loss: 5.5856 - Generator Validation Loss: 0.9549
#    - Discriminator Train Loss: 0.5219 - Discriminator Validation Loss: 4.3141
# Validation loss improved. Best model updated.
# Epoch 205/1000
#    - Generator Train Loss: 6.0308 - Generator Validation Loss: 1.9033
#    - Discriminator Train Loss: 0.4877 - Discriminator Validation Loss: 1.5498
# No improvement for 1 epoch(s).
# Epoch 206/1000
#    - Generator Train Loss: 3.4841 - Generator Validation Loss: 0.9943
#    - Discriminator Train Loss: 1.1170 - Discriminator Validation Loss: 3.5323
# No improvement for 2 epoch(s).
# Epoch 207/1000
#    - Generator Train Loss: 5.7330 - Generator Validation Loss: 1.0847
#    - Discriminator Train Loss: 0.5385 - Discriminator Validation Loss: 2.7184
# No improvement for 3 epoch(s).
# Epoch 208/1000
#    - Generator Train Loss: 4.0229 - Generator Validation Loss: 2.1523
#    - Discriminator Train Loss: 0.9328 - Discriminator Validation Loss: 1.3968
# No improvement for 4 epoch(s).
# Epoch 209/1000
#    - Generator Train Loss: 4.6578 - Generator Validation Loss: 1.1411
#    - Discriminator Train Loss: 0.7778 - Discriminator Validation Loss: 2.4791
# No improvement for 5 epoch(s).
# Epoch 210/1000
#    - Generator Train Loss: 4.9141 - Generator Validation Loss: 1.4420
#    - Discriminator Train Loss: 0.7964 - Discriminator Validation Loss: 1.8873
# No improvement for 6 epoch(s).
# Epoch 211/1000
#    - Generator Train Loss: 5.2773 - Generator Validation Loss: 1.0112
#    - Discriminator Train Loss: 0.6458 - Discriminator Validation Loss: 3.9380
# No improvement for 7 epoch(s).
# Epoch 212/1000
#    - Generator Train Loss: 6.5856 - Generator Validation Loss: 1.1039
#    - Discriminator Train Loss: 0.4555 - Discriminator Validation Loss: 2.6877
# No improvement for 8 epoch(s).
# Epoch 213/1000
#    - Generator Train Loss: 5.8945 - Generator Validation Loss: 0.9490
#    - Discriminator Train Loss: 0.6059 - Discriminator Validation Loss: 5.1263
# Validation loss improved. Best model updated.
# Epoch 214/1000
#    - Generator Train Loss: 5.8987 - Generator Validation Loss: 1.0635
#    - Discriminator Train Loss: 0.6202 - Discriminator Validation Loss: 2.8682
# No improvement for 1 epoch(s).
# Epoch 215/1000
#    - Generator Train Loss: 5.3854 - Generator Validation Loss: 0.9443
#    - Discriminator Train Loss: 0.5814 - Discriminator Validation Loss: 4.8981
# Validation loss improved. Best model updated.
# Epoch 216/1000
#    - Generator Train Loss: 5.9325 - Generator Validation Loss: 1.2903
#    - Discriminator Train Loss: 0.5632 - Discriminator Validation Loss: 2.1062
# No improvement for 1 epoch(s).
# Epoch 217/1000
#    - Generator Train Loss: 5.6677 - Generator Validation Loss: 0.9678
#    - Discriminator Train Loss: 0.5473 - Discriminator Validation Loss: 4.1475
# No improvement for 2 epoch(s).
# Epoch 218/1000
#    - Generator Train Loss: 6.2783 - Generator Validation Loss: 3.4630
#    - Discriminator Train Loss: 0.4534 - Discriminator Validation Loss: 1.8808
# No improvement for 3 epoch(s).
# Epoch 219/1000
#    - Generator Train Loss: 5.5221 - Generator Validation Loss: 0.9242
#    - Discriminator Train Loss: 0.7443 - Discriminator Validation Loss: 5.4817
# Validation loss improved. Best model updated.
# Epoch 220/1000
#    - Generator Train Loss: 5.3158 - Generator Validation Loss: 1.0205
#    - Discriminator Train Loss: 0.6291 - Discriminator Validation Loss: 3.5062
# No improvement for 1 epoch(s).
# Epoch 221/1000
#    - Generator Train Loss: 5.8142 - Generator Validation Loss: 2.2829
#    - Discriminator Train Loss: 0.5751 - Discriminator Validation Loss: 1.4685
# No improvement for 2 epoch(s).
# Epoch 222/1000
#    - Generator Train Loss: 2.5115 - Generator Validation Loss: 1.9267
#    - Discriminator Train Loss: 1.3683 - Discriminator Validation Loss: 1.4347
# No improvement for 3 epoch(s).
# Epoch 223/1000
#    - Generator Train Loss: 4.2609 - Generator Validation Loss: 0.9284
# ...
# No improvement for 26 epoch(s).
# Epoch 347/1000
#    - Generator Train Loss: 7.6599 - Generator Validation Loss: 1.1410
#    - Discriminator Train Loss: 0.4356 - Discriminator Validation Loss: 2.7775
# No improvement for 27 epoch(s).
# Epoch 348/1000
#    - Generator Train Loss: 6.9448 - Generator Validation Loss: 0.9467
#    - Discriminator Train Loss: 0.3165 - Discriminator Validation Loss: 5.6626
# No improvement for 28 epoch(s).
# Epoch 349/1000
#    - Generator Train Loss: 6.9900 - Generator Validation Loss: 0.9682
#    - Discriminator Train Loss: 0.4397 - Discriminator Validation Loss: 4.7792
# No improvement for 29 epoch(s).
# Epoch 350/1000
#    - Generator Train Loss: 6.9071 - Generator Validation Loss: 1.0879
#    - Discriminator Train Loss: 0.3975 - Discriminator Validation Loss: 2.9392
# No improvement for 30 epoch(s).
# Epoch 351/1000
#    - Generator Train Loss: 6.6873 - Generator Validation Loss: 1.0184
#    - Discriminator Train Loss: 0.6042 - Discriminator Validation Loss: 3.5883
# No improvement for 31 epoch(s).
# Epoch 352/1000
#    - Generator Train Loss: 6.6884 - Generator Validation Loss: 0.9663
#    - Discriminator Train Loss: 0.3821 - Discriminator Validation Loss: 3.9226
# No improvement for 32 epoch(s).
# Epoch 353/1000
#    - Generator Train Loss: 6.8453 - Generator Validation Loss: 0.9630
#    - Discriminator Train Loss: 0.4189 - Discriminator Validation Loss: 4.8027
# No improvement for 33 epoch(s).
# Epoch 354/1000
#    - Generator Train Loss: 7.6622 - Generator Validation Loss: 1.6358
#    - Discriminator Train Loss: 0.3458 - Discriminator Validation Loss: 1.9052
# No improvement for 34 epoch(s).
# Epoch 355/1000
#    - Generator Train Loss: 7.1986 - Generator Validation Loss: 0.9583
#    - Discriminator Train Loss: 0.4564 - Discriminator Validation Loss: 4.5506
# No improvement for 35 epoch(s).
# Epoch 356/1000
#    - Generator Train Loss: 6.9526 - Generator Validation Loss: 0.9171
#    - Discriminator Train Loss: 0.3305 - Discriminator Validation Loss: 6.2121
# No improvement for 36 epoch(s).
# Epoch 357/1000
#    - Generator Train Loss: 7.0128 - Generator Validation Loss: 0.9182
#    - Discriminator Train Loss: 0.3644 - Discriminator Validation Loss: 6.8316
# No improvement for 37 epoch(s).
# Epoch 358/1000
#    - Generator Train Loss: 7.7220 - Generator Validation Loss: 0.9512
#    - Discriminator Train Loss: 0.2437 - Discriminator Validation Loss: 4.3886
# No improvement for 38 epoch(s).
# Epoch 359/1000
#    - Generator Train Loss: 8.4179 - Generator Validation Loss: 0.9298
#    - Discriminator Train Loss: 0.2950 - Discriminator Validation Loss: 6.2657
# No improvement for 39 epoch(s).
# Epoch 360/1000
#    - Generator Train Loss: 7.7555 - Generator Validation Loss: 1.0589
#    - Discriminator Train Loss: 0.3061 - Discriminator Validation Loss: 3.2756
# No improvement for 40 epoch(s).
# Epoch 361/1000
#    - Generator Train Loss: 6.8845 - Generator Validation Loss: 0.9305
#    - Discriminator Train Loss: 0.3979 - Discriminator Validation Loss: 6.2689
# No improvement for 41 epoch(s).
# Epoch 362/1000
#    - Generator Train Loss: 7.5410 - Generator Validation Loss: 0.9352
#    - Discriminator Train Loss: 0.3221 - Discriminator Validation Loss: 5.3091
# No improvement for 42 epoch(s).
# Epoch 363/1000
#    - Generator Train Loss: 7.2502 - Generator Validation Loss: 0.9371
#    - Discriminator Train Loss: 0.4368 - Discriminator Validation Loss: 5.1059
# No improvement for 43 epoch(s).
# Epoch 364/1000
#    - Generator Train Loss: 7.1552 - Generator Validation Loss: 1.2463
#    - Discriminator Train Loss: 0.2864 - Discriminator Validation Loss: 2.2886
# No improvement for 44 epoch(s).
# Epoch 365/1000
#    - Generator Train Loss: 8.4807 - Generator Validation Loss: 0.9230
#    - Discriminator Train Loss: 0.4295 - Discriminator Validation Loss: 5.2920
# No improvement for 45 epoch(s).
# Epoch 366/1000
#    - Generator Train Loss: 7.0243 - Generator Validation Loss: 0.9578
#    - Discriminator Train Loss: 0.3799 - Discriminator Validation Loss: 4.4251
# No improvement for 46 epoch(s).
# Epoch 367/1000
#    - Generator Train Loss: 8.1715 - Generator Validation Loss: 0.9218
#    - Discriminator Train Loss: 0.3143 - Discriminator Validation Loss: 6.8131
# No improvement for 47 epoch(s).
# Epoch 368/1000
#    - Generator Train Loss: 7.3074 - Generator Validation Loss: 0.9459
#    - Discriminator Train Loss: 0.3579 - Discriminator Validation Loss: 4.8669
# No improvement for 48 epoch(s).
# Epoch 369/1000
#    - Generator Train Loss: 7.3649 - Generator Validation Loss: 0.9466
#    - Discriminator Train Loss: 0.2624 - Discriminator Validation Loss: 4.7571
# No improvement for 49 epoch(s).
# Epoch 370/1000
#    - Generator Train Loss: 7.7850 - Generator Validation Loss: 0.9987
#    - Discriminator Train Loss: 0.2857 - Discriminator Validation Loss: 4.3171
# No improvement for 50 epoch(s).
# Epoch 371/1000
#    - Generator Train Loss: 8.3569 - Generator Validation Loss: 0.9388
#    - Discriminator Train Loss: 0.2553 - Discriminator Validation Loss: 6.4645
# No improvement for 51 epoch(s).
# Epoch 372/1000
#    - Generator Train Loss: 7.6127 - Generator Validation Loss: 1.4686
#    - Discriminator Train Loss: 0.4078 - Discriminator Validation Loss: 2.1869
# No improvement for 52 epoch(s).
# Epoch 373/1000
#    - Generator Train Loss: 7.2692 - Generator Validation Loss: 0.9345
#    - Discriminator Train Loss: 0.3456 - Discriminator Validation Loss: 7.2663
# No improvement for 53 epoch(s).
# Epoch 374/1000
#    - Generator Train Loss: 6.8125 - Generator Validation Loss: 1.6341
#    - Discriminator Train Loss: 0.4662 - Discriminator Validation Loss: 1.7138
# No improvement for 54 epoch(s).
# Epoch 375/1000
#    - Generator Train Loss: 7.3536 - Generator Validation Loss: 0.9640
#    - Discriminator Train Loss: 0.4249 - Discriminator Validation Loss: 4.3210
# No improvement for 55 epoch(s).
# Epoch 376/1000
#    - Generator Train Loss: 7.0561 - Generator Validation Loss: 0.9708
#    - Discriminator Train Loss: 0.4837 - Discriminator Validation Loss: 4.0339
# No improvement for 56 epoch(s).
# Epoch 377/1000
#    - Generator Train Loss: 7.2314 - Generator Validation Loss: 0.9444
#    - Discriminator Train Loss: 0.3323 - Discriminator Validation Loss: 6.1259
# No improvement for 57 epoch(s).
# Epoch 378/1000
#    - Generator Train Loss: 8.4842 - Generator Validation Loss: 1.8121
#    - Discriminator Train Loss: 0.2099 - Discriminator Validation Loss: 1.5056
# No improvement for 58 epoch(s).
# Epoch 379/1000
#    - Generator Train Loss: 7.1928 - Generator Validation Loss: 0.9231
#    - Discriminator Train Loss: 0.3984 - Discriminator Validation Loss: 6.1253
# No improvement for 59 epoch(s).
# Epoch 380/1000
#    - Generator Train Loss: 5.9137 - Generator Validation Loss: 2.0851
#    - Discriminator Train Loss: 0.6925 - Discriminator Validation Loss: 1.4953
# No improvement for 60 epoch(s).
# Epoch 381/1000
#    - Generator Train Loss: 6.8789 - Generator Validation Loss: 1.0419
#    - Discriminator Train Loss: 0.4424 - Discriminator Validation Loss: 3.0940
# No improvement for 61 epoch(s).
# Epoch 382/1000
#    - Generator Train Loss: 7.0210 - Generator Validation Loss: 0.9455
#    - Discriminator Train Loss: 0.3155 - Discriminator Validation Loss: 5.6980
# No improvement for 62 epoch(s).
# Epoch 383/1000
#    - Generator Train Loss: 8.3373 - Generator Validation Loss: 1.2249
#    - Discriminator Train Loss: 0.3844 - Discriminator Validation Loss: 2.3261
# No improvement for 63 epoch(s).
# Epoch 384/1000
#    - Generator Train Loss: 8.4714 - Generator Validation Loss: 1.2990
#    - Discriminator Train Loss: 0.2212 - Discriminator Validation Loss: 2.1673
# No improvement for 64 epoch(s).
# Epoch 385/1000
#    - Generator Train Loss: 6.9802 - Generator Validation Loss: 0.9961
#    - Discriminator Train Loss: 0.3812 - Discriminator Validation Loss: 3.7624
# No improvement for 65 epoch(s).
# Epoch 386/1000
#    - Generator Train Loss: 7.2783 - Generator Validation Loss: 0.9421
#    - Discriminator Train Loss: 0.3514 - Discriminator Validation Loss: 5.8298
# No improvement for 66 epoch(s).
# Epoch 387/1000
#    - Generator Train Loss: 7.1557 - Generator Validation Loss: 0.9561
#    - Discriminator Train Loss: 0.3645 - Discriminator Validation Loss: 4.0264
# No improvement for 67 epoch(s).
# Epoch 388/1000
#    - Generator Train Loss: 7.3269 - Generator Validation Loss: 1.6747
#    - Discriminator Train Loss: 0.3813 - Discriminator Validation Loss: 1.8323
# No improvement for 68 epoch(s).
# Epoch 389/1000
#    - Generator Train Loss: 7.7833 - Generator Validation Loss: 0.9437
#    - Discriminator Train Loss: 0.3435 - Discriminator Validation Loss: 6.2064
# No improvement for 69 epoch(s).
# Epoch 390/1000
#    - Generator Train Loss: 8.0620 - Generator Validation Loss: 0.9808
#    - Discriminator Train Loss: 0.2187 - Discriminator Validation Loss: 4.1369
# No improvement for 70 epoch(s).
# Epoch 391/1000
#    - Generator Train Loss: 8.2173 - Generator Validation Loss: 0.9380
#    - Discriminator Train Loss: 0.2594 - Discriminator Validation Loss: 5.8070
# No improvement for 71 epoch(s).
# Epoch 392/1000
#    - Generator Train Loss: 8.4692 - Generator Validation Loss: 1.0975
#    - Discriminator Train Loss: 0.2403 - Discriminator Validation Loss: 2.7281
# No improvement for 72 epoch(s).
# Epoch 393/1000
#    - Generator Train Loss: 6.7956 - Generator Validation Loss: 1.1106
#    - Discriminator Train Loss: 0.5475 - Discriminator Validation Loss: 2.9948
# No improvement for 73 epoch(s).
# Epoch 394/1000
#    - Generator Train Loss: 7.3458 - Generator Validation Loss: 0.9731
#    - Discriminator Train Loss: 0.3691 - Discriminator Validation Loss: 4.3565
# No improvement for 74 epoch(s).
# Epoch 395/1000
#    - Generator Train Loss: 7.6897 - Generator Validation Loss: 0.9635
#    - Discriminator Train Loss: 0.3151 - Discriminator Validation Loss: 4.9837
# No improvement for 75 epoch(s).
# Epoch 396/1000
#    - Generator Train Loss: 7.7114 - Generator Validation Loss: 0.9821
#    - Discriminator Train Loss: 0.3656 - Discriminator Validation Loss: 4.5531
# No improvement for 76 epoch(s).
# Epoch 397/1000
#    - Generator Train Loss: 7.2784 - Generator Validation Loss: 0.9216
#    - Discriminator Train Loss: 0.2842 - Discriminator Validation Loss: 5.9357
# No improvement for 77 epoch(s).
# Epoch 398/1000
#    - Generator Train Loss: 7.0879 - Generator Validation Loss: 1.2909
#    - Discriminator Train Loss: 0.3919 - Discriminator Validation Loss: 2.0119
# No improvement for 78 epoch(s).
# Epoch 399/1000
#    - Generator Train Loss: 7.0190 - Generator Validation Loss: 0.9805
#    - Discriminator Train Loss: 0.4362 - Discriminator Validation Loss: 4.0482
# No improvement for 79 epoch(s).
# Epoch 400/1000
#    - Generator Train Loss: 7.5028 - Generator Validation Loss: 0.9555
#    - Discriminator Train Loss: 0.3150 - Discriminator Validation Loss: 5.7449
# No improvement for 80 epoch(s).
# Epoch 401/1000
#    - Generator Train Loss: 8.3791 - Generator Validation Loss: 0.9259
#    - Discriminator Train Loss: 0.1690 - Discriminator Validation Loss: 6.9954
# No improvement for 81 epoch(s).
# Epoch 402/1000
#    - Generator Train Loss: 8.0852 - Generator Validation Loss: 0.9179
#    - Discriminator Train Loss: 0.1908 - Discriminator Validation Loss: 8.2584
# No improvement for 82 epoch(s).
# Epoch 403/1000
#    - Generator Train Loss: 7.6698 - Generator Validation Loss: 1.6822
#    - Discriminator Train Loss: 0.3458 - Discriminator Validation Loss: 1.6921
# No improvement for 83 epoch(s).
# Epoch 404/1000
#    - Generator Train Loss: 8.0838 - Generator Validation Loss: 0.9694
#    - Discriminator Train Loss: 0.3899 - Discriminator Validation Loss: 3.5585
# No improvement for 84 epoch(s).
# Epoch 405/1000
#    - Generator Train Loss: 7.6268 - Generator Validation Loss: 0.9478
#    - Discriminator Train Loss: 0.2865 - Discriminator Validation Loss: 6.5433
# No improvement for 85 epoch(s).
# Epoch 406/1000
#    - Generator Train Loss: 7.9721 - Generator Validation Loss: 0.9561
#    - Discriminator Train Loss: 0.2209 - Discriminator Validation Loss: 4.8433
# No improvement for 86 epoch(s).
# Epoch 407/1000
#    - Generator Train Loss: 7.5981 - Generator Validation Loss: 1.1338
#    - Discriminator Train Loss: 0.3970 - Discriminator Validation Loss: 2.7985
# No improvement for 87 epoch(s).
# Epoch 408/1000
#    - Generator Train Loss: 7.3227 - Generator Validation Loss: 0.9583
#    - Discriminator Train Loss: 0.3627 - Discriminator Validation Loss: 4.7173
# No improvement for 88 epoch(s).
# Epoch 409/1000
#    - Generator Train Loss: 8.6474 - Generator Validation Loss: 0.9565
#    - Discriminator Train Loss: 0.2884 - Discriminator Validation Loss: 4.8996
# No improvement for 89 epoch(s).
# Epoch 410/1000
#    - Generator Train Loss: 8.0452 - Generator Validation Loss: 0.9478
#    - Discriminator Train Loss: 0.3170 - Discriminator Validation Loss: 4.8427
# No improvement for 90 epoch(s).
# Epoch 411/1000
#    - Generator Train Loss: 8.6964 - Generator Validation Loss: 0.9197
#    - Discriminator Train Loss: 0.1760 - Discriminator Validation Loss: 6.1537
# No improvement for 91 epoch(s).
# Epoch 412/1000
#    - Generator Train Loss: 8.1865 - Generator Validation Loss: 0.9647
#    - Discriminator Train Loss: 0.2779 - Discriminator Validation Loss: 5.4544
# No improvement for 92 epoch(s).
# Epoch 413/1000
#    - Generator Train Loss: 8.4242 - Generator Validation Loss: 1.0031
#    - Discriminator Train Loss: 0.2248 - Discriminator Validation Loss: 4.7154
# No improvement for 93 epoch(s).
# Epoch 414/1000
#    - Generator Train Loss: 7.7313 - Generator Validation Loss: 1.1168
#    - Discriminator Train Loss: 0.4406 - Discriminator Validation Loss: 2.9478
# No improvement for 94 epoch(s).
# Epoch 415/1000
#    - Generator Train Loss: 7.4384 - Generator Validation Loss: 1.7223
#    - Discriminator Train Loss: 0.5198 - Discriminator Validation Loss: 1.5381
# No improvement for 95 epoch(s).
# Epoch 416/1000
#    - Generator Train Loss: 7.4457 - Generator Validation Loss: 0.9639
#    - Discriminator Train Loss: 0.2862 - Discriminator Validation Loss: 4.7510
# No improvement for 96 epoch(s).
# Epoch 417/1000
#    - Generator Train Loss: 7.5509 - Generator Validation Loss: 1.9547
#    - Discriminator Train Loss: 0.3414 - Discriminator Validation Loss: 1.4752
# No improvement for 97 epoch(s).
# Epoch 418/1000
#    - Generator Train Loss: 6.5666 - Generator Validation Loss: 0.9579
#    - Discriminator Train Loss: 0.5705 - Discriminator Validation Loss: 4.3751
# No improvement for 98 epoch(s).
# Epoch 419/1000
#    - Generator Train Loss: 7.1557 - Generator Validation Loss: 0.9630
#    - Discriminator Train Loss: 0.3446 - Discriminator Validation Loss: 4.7766
# No improvement for 99 epoch(s).
# Epoch 420/1000
#    - Generator Train Loss: 8.3497 - Generator Validation Loss: 0.9955
#    - Discriminator Train Loss: 0.2062 - Discriminator Validation Loss: 3.9673
# No improvement for 100 epoch(s).
# Early stopping triggered!

# %%
# save the best model
os.makedirs('./gen_models/models', exist_ok=True)
if gen_best_model_state is not None:
    torch.save(gen_best_model_state, gen_best_model_filename)
    print(f"Best model saved to {gen_best_model_filename}")
# Out:
# Best model saved to ./gen_models/best_model_0.9040541272414359_20250427_174602.pth

# %% [markdown]
# # Model Testing

# %%
generator.load_state_dict(torch.load(gen_best_model_filename, map_location=device, weights_only=True))
generator.eval()

# Arrays to store all predictions and all ground truth masks
pred_mask_all, target_all = [], []

with torch.no_grad():
    for batch in test_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)

        # Make test predictions
        pred_mask = generator(images)

        pred_mask_all.append(pred_mask.cpu().numpy())
        target_all.append(target.cpu().numpy())

    # Concatenate all batches into a single array for performance                        
    preds = np.concatenate(pred_mask_all, axis=0)   
    trues = np.concatenate(target_all, axis=0)        

    # Squeeze from 4 dimensions into 3 since we use only one channel
    if preds.ndim == 4 and preds.shape[1] == 1:
        preds = preds.squeeze(1)
        trues = trues.squeeze(1)

    # Binarize predictions
    preds  = (preds > 0.5).astype(np.uint8)
    trues  = trues.astype(np.uint8)

    preds = preds.flatten()
    trues = trues.flatten()

    # Calculate TP, FP, FN for evaluation metrics
    tp = np.logical_and(preds==1, trues==1).sum()
    fp = np.logical_and(preds==1, trues==0).sum()
    fn = np.logical_and(preds==0, trues==1).sum()

    # Calculate evaluation metrics
    smooth = 1e-6
    dice = (2*tp + smooth) / (2*tp + fp + fn + smooth)
    iou  = (tp + smooth)   / (tp + fp + fn + smooth)
    recall = tp / (tp + fn + smooth)

                             
    # Dice coefficient
    # IoU (Jaccard Index)
    # Recall - We care a lot about false negatives
    metrics = {
        'Dice Coefficient': dice,
        'IoU': iou,
        'Recall': recall
        }
    
    print("\n **Test Results:**")
    for key, value in metrics.items():
        print(f"{key}: {value:.4f}")
# Out:
#  **Test Results:**
# Dice Coefficient: 0.0586
# IoU: 0.0302
# Recall: 0.2683
