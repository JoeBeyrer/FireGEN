# %%
from utils import *
from models import *
from loss import *
import numpy as np
import os
import matplotlib.pyplot as plt
from matplotlib import colors
from datetime import datetime

# %%
train_path = '../next_day_fires/next_day_wildfire_spread_train*'
val_path = '../next_day_fires/next_day_wildfire_spread_eval*'
test_path = '../next_day_fires/next_day_wildfire_spread_test*'
features = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask', 'FireMask']

# %% [markdown]
# # Load Data

# %% [markdown]
# ## Training Data

# %%
train_dataset = get_dataset(
      train_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

train_inputs, train_labels = next(iter(train_dataset))

print(train_inputs.shape)
print(train_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
titles = [
  'Elevation',
  'Wind\ndirection',
  'Wind\nvelocity',
  'Min\ntemp',
  'Max\ntemp',
  'Humidity',
  'Precip',
  'Drought',
  'Vegetation',
  'Population\ndensity',
  'Energy\nrelease\ncomponent',
  'Previous\nfire\nmask',
  'Fire\nmask'
]

n_rows = 5
n_features = train_inputs.shape[3] 
CMAP = colors.ListedColormap(['black', 'silver', 'orangered'])
BOUNDS = [-1, -0.1, 0.001, 1]
NORM = colors.BoundaryNorm(BOUNDS, CMAP.N)
keys = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask']

# %%
# fig = plt.figure(figsize=(20,8))

# for i in range(n_rows):
#   for j in range(n_features + 1):
#     plt.subplot(n_rows, n_features + 1, i * (n_features + 1) + j + 1)
#     if i == 0:
#       plt.title(titles[j], fontsize=15)
#     if j < n_features - 1:
#       plt.imshow(train_inputs[i, j, :, :], cmap='viridis')
#     if j == n_features - 1:
#       plt.imshow(train_inputs[i, -1, :, :], cmap=CMAP, norm=NORM)
#     if j == n_features:
#       plt.imshow(train_labels[i, 0, :, :], cmap=CMAP, norm=NORM) 
#     plt.axis('off')
# plt.tight_layout()

# %% [markdown]
# ## Vlidation Data

# %%
val_dataset = get_dataset(
      val_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

val_inputs, val_labels = next(iter(val_dataset))

print(val_inputs.shape)
print(val_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %% [markdown]
# ## Test Data

# %%
test_dataset = get_dataset(
      test_path,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)

test_inputs, test_labels = next(iter(val_dataset))

print(test_inputs.shape)
print(test_labels.shape)
# Out:
# torch.Size([100, 12, 32, 32])
# torch.Size([100, 1, 32, 32])

# %%
# Build DataLoader
train_loader = DataLoader(train_dataset, batch_size=None, num_workers=0, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=None, num_workers=0, pin_memory=True)
test_loader = DataLoader(test_dataset, batch_size=None, num_workers=0, pin_memory=True)

# %% [markdown]
# # Model Initialization

# %%
folder_path = './gen_models'
gen_input_channels = 12
disc_input_channels = 13
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ### Hyperparameters

# %%
#  Hyperparameters
kernel_size = 4 # DO NOT CHANGE
stride = 2 # DO NOT CHANGE
padding = 1 # DO NOT CHANGE
dropout = 0.5

gen_lr = 4e-4
disc_lr = 1e-4

alpha = 1
lambd = 2
pos_weight = 30
bce_weight = 0.5

num_epochs = 1000
patience = 100

# %% [markdown]
# ### Model Initialization

# %%
generator = Generator(gen_input_channels, kernel_size, stride, padding, dropout)
discriminator = Discriminator(disc_input_channels, kernel_size, stride, padding)

generator.apply(init_weights)
discriminator.apply(init_weights)

generator.to(device)
discriminator.to(device)
# Out:
# Discriminator(
#   (e1): Conv2d(13, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (lr1): LeakyReLU(negative_slope=0.2)
#   (e2): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr2): LeakyReLU(negative_slope=0.2)
#   (e3): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (eb3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (lr3): LeakyReLU(negative_slope=0.2)
#   (output): Conv2d(256, 1, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
# )

# %% [markdown]
# # Model Training

# %%
gen_best_val_loss = float('inf')
epochs_no_improve = 0
gen_best_model_state = None
bgen_est_model_filename = None

# Optimizers and loss functions
gen_optimizer = torch.optim.Adam(generator.parameters(), lr=gen_lr, betas=(0.5, 0.999))
disc_optimizer = torch.optim.Adam(discriminator.parameters(), lr=disc_lr, betas=(0.5, 0.999))
gen_criterion = GenLoss(alpha=alpha, lambd=lambd, pos_weight=torch.tensor([pos_weight]).to(device), bce_weight=bce_weight)
disc_criterion = DiscLoss()
torch.autograd.set_detect_anomaly(True)
# Train over the entire dataset every epoch
for epoch in range(num_epochs):
    if epoch == 50:
        gen_best_val_loss = float('inf')
        gen_criterion.alpha = 0.5
        for p in discriminator.parameters():
            p.requires_grad = True
    elif epoch == 0:
        gen_criterion.alpha = 0
        for p in discriminator.parameters():
            p.requires_grad = False
            
    generator.train()
    #discriminator.train()

    gen_total_loss = 0
    disc_total_loss = 0

    # Train in batches 
    for batch in train_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)
        # Update Discriminator
        disc_optimizer.zero_grad()

        # Generate fake images
        with torch.no_grad():
            generated = generator(images)
        generated_detached = generated.detach()

        # Discriminator loss
        #real_pred = discriminator(target, images)
        #fake_pred = discriminator(generated_detached, images)
        #disc_loss = disc_criterion(real_pred, fake_pred)

        #if epoch > 49:
        #    disc_loss.backward()
        #    disc_optimizer.step()

        # Update generator
        gen_optimizer.zero_grad()

        # Re-forward generator
        generated = generator(images)
        #gen_pred = discriminator(generated, images)
        gen_loss = gen_criterion(generated, target)

        gen_loss.backward()
        gen_optimizer.step()

        # Add loss to totals
        gen_total_loss = gen_total_loss + gen_loss.item()
        #disc_total_loss = disc_total_loss + disc_loss.item()

    # Average the loss over all batches
    gen_avg_loss = gen_total_loss / len(train_loader)
    #disc_avg_loss = disc_total_loss / len(train_loader)


    # Now, validate the model
    generator.eval()
    #discriminator.eval()
    gen_val_loss = 0
    disc_val_loss = 0

    # Gradients are not used as validation is used to find the best model without further optimization
    with torch.no_grad():
        # Validate in batches
        for batch in val_loader:
            images, target = batch
            images = images.to(device)
            target = target.to(device)
            
            # Make predictions on the validation images
            generated = generator(images)
            #gen_pred = discriminator(generated, images)
            #real_pred = discriminator(target, images)

            # Calculate the loss
            gen_loss = gen_criterion(generated, target)
            #disc_loss = disc_criterion(real_pred, gen_pred)
            gen_val_loss = gen_val_loss + gen_loss.item()
            #disc_val_loss = disc_val_loss + disc_loss.item()


    
    # Average the validation loss over all batches
    gen_avg_val_loss = gen_val_loss / len(val_loader)
    #disc_avg_val_loss = disc_val_loss / len(val_loader)
    
    print(f"Epoch {epoch + 1}/{num_epochs}\
          \n   - Generator Train Loss: {gen_avg_loss:.4f} - Generator Validation Loss: {gen_avg_val_loss:.4f}"
          )

    # Best model saving & early stopping
    if gen_avg_val_loss < gen_best_val_loss:
        gen_best_val_loss = gen_avg_val_loss
        epochs_no_improve = 0
        gen_best_model_state = generator.state_dict() 
        gen_best_model_filename = f"{folder_path}/best_model_{str(gen_best_val_loss)}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.pth"
        print("Validation loss improved. Best model updated.")
    else:
        epochs_no_improve += 1
        print(f"No improvement for {epochs_no_improve} epoch(s).")
    
    if epochs_no_improve >= patience:
        print("Early stopping triggered!")
        break
# Out:
# Epoch 1/1000
#    - Generator Train Loss: 0.8947 - Generator Validation Loss: 0.9186
# Validation loss improved. Best model updated.
# Epoch 2/1000
#    - Generator Train Loss: 0.8683 - Generator Validation Loss: 0.9048
# Validation loss improved. Best model updated.
# Epoch 3/1000
#    - Generator Train Loss: 0.8634 - Generator Validation Loss: 0.9066
# No improvement for 1 epoch(s).
# Epoch 4/1000
#    - Generator Train Loss: 0.8652 - Generator Validation Loss: 0.9162
# No improvement for 2 epoch(s).
# Epoch 5/1000
#    - Generator Train Loss: 0.8579 - Generator Validation Loss: 0.9274
# No improvement for 3 epoch(s).
# Epoch 6/1000
#    - Generator Train Loss: 0.8611 - Generator Validation Loss: 0.8926
# Validation loss improved. Best model updated.
# Epoch 7/1000
#    - Generator Train Loss: 0.8516 - Generator Validation Loss: 0.9014
# No improvement for 1 epoch(s).
# Epoch 8/1000
#    - Generator Train Loss: 0.8500 - Generator Validation Loss: 0.9134
# No improvement for 2 epoch(s).
# Epoch 9/1000
#    - Generator Train Loss: 0.8511 - Generator Validation Loss: 0.9178
# No improvement for 3 epoch(s).
# Epoch 10/1000
#    - Generator Train Loss: 0.8471 - Generator Validation Loss: 0.8959
# No improvement for 4 epoch(s).
# Epoch 11/1000
#    - Generator Train Loss: 0.8499 - Generator Validation Loss: 0.9036
# No improvement for 5 epoch(s).
# Epoch 12/1000
#    - Generator Train Loss: 0.8461 - Generator Validation Loss: 0.9018
# No improvement for 6 epoch(s).
# Epoch 13/1000
#    - Generator Train Loss: 0.8464 - Generator Validation Loss: 0.8904
# Validation loss improved. Best model updated.
# Epoch 14/1000
#    - Generator Train Loss: 0.8438 - Generator Validation Loss: 0.8995
# No improvement for 1 epoch(s).
# Epoch 15/1000
#    - Generator Train Loss: 0.8403 - Generator Validation Loss: 0.9034
# No improvement for 2 epoch(s).
# Epoch 16/1000
#    - Generator Train Loss: 0.8405 - Generator Validation Loss: 0.8964
# No improvement for 3 epoch(s).
# Epoch 17/1000
#    - Generator Train Loss: 0.8416 - Generator Validation Loss: 0.8925
# No improvement for 4 epoch(s).
# Epoch 18/1000
#    - Generator Train Loss: 0.8435 - Generator Validation Loss: 0.9045
# No improvement for 5 epoch(s).
# Epoch 19/1000
#    - Generator Train Loss: 0.8405 - Generator Validation Loss: 0.9073
# No improvement for 6 epoch(s).
# Epoch 20/1000
#    - Generator Train Loss: 0.8410 - Generator Validation Loss: 0.8978
# No improvement for 7 epoch(s).
# Epoch 21/1000
#    - Generator Train Loss: 0.8397 - Generator Validation Loss: 0.8920
# No improvement for 8 epoch(s).
# Epoch 22/1000
#    - Generator Train Loss: 0.8336 - Generator Validation Loss: 0.8981
# No improvement for 9 epoch(s).
# Epoch 23/1000
#    - Generator Train Loss: 0.8413 - Generator Validation Loss: 0.9173
# No improvement for 10 epoch(s).
# Epoch 24/1000
#    - Generator Train Loss: 0.8328 - Generator Validation Loss: 0.8985
# No improvement for 11 epoch(s).
# Epoch 25/1000
#    - Generator Train Loss: 0.8324 - Generator Validation Loss: 0.8808
# Validation loss improved. Best model updated.
# Epoch 26/1000
#    - Generator Train Loss: 0.8338 - Generator Validation Loss: 0.8954
# No improvement for 1 epoch(s).
# Epoch 27/1000
#    - Generator Train Loss: 0.8300 - Generator Validation Loss: 0.8944
# No improvement for 2 epoch(s).
# Epoch 28/1000
#    - Generator Train Loss: 0.8229 - Generator Validation Loss: 0.8667
# Validation loss improved. Best model updated.
# Epoch 29/1000
#    - Generator Train Loss: 0.8205 - Generator Validation Loss: 0.8890
# No improvement for 1 epoch(s).
# Epoch 30/1000
#    - Generator Train Loss: 0.8209 - Generator Validation Loss: 0.8794
# No improvement for 2 epoch(s).
# Epoch 31/1000
#    - Generator Train Loss: 0.8145 - Generator Validation Loss: 0.8910
# No improvement for 3 epoch(s).
# Epoch 32/1000
#    - Generator Train Loss: 0.8117 - Generator Validation Loss: 0.9164
# No improvement for 4 epoch(s).
# Epoch 33/1000
#    - Generator Train Loss: 0.8171 - Generator Validation Loss: 0.9012
# No improvement for 5 epoch(s).
# Epoch 34/1000
#    - Generator Train Loss: 0.8119 - Generator Validation Loss: 0.8896
# No improvement for 6 epoch(s).
# Epoch 35/1000
#    - Generator Train Loss: 0.8103 - Generator Validation Loss: 0.8660
# Validation loss improved. Best model updated.
# Epoch 36/1000
#    - Generator Train Loss: 0.8083 - Generator Validation Loss: 0.8846
# No improvement for 1 epoch(s).
# Epoch 37/1000
#    - Generator Train Loss: 0.8077 - Generator Validation Loss: 0.8901
# No improvement for 2 epoch(s).
# Epoch 38/1000
#    - Generator Train Loss: 0.8092 - Generator Validation Loss: 0.8685
# No improvement for 3 epoch(s).
# Epoch 39/1000
#    - Generator Train Loss: 0.8044 - Generator Validation Loss: 0.8681
# No improvement for 4 epoch(s).
# Epoch 40/1000
#    - Generator Train Loss: 0.8013 - Generator Validation Loss: 0.8572
# Validation loss improved. Best model updated.
# Epoch 41/1000
#    - Generator Train Loss: 0.8025 - Generator Validation Loss: 0.8572
# Validation loss improved. Best model updated.
# Epoch 42/1000
#    - Generator Train Loss: 0.8028 - Generator Validation Loss: 0.9005
# No improvement for 1 epoch(s).
# Epoch 43/1000
#    - Generator Train Loss: 0.8037 - Generator Validation Loss: 0.8864
# No improvement for 2 epoch(s).
# Epoch 44/1000
#    - Generator Train Loss: 0.8059 - Generator Validation Loss: 0.9104
# No improvement for 3 epoch(s).
# Epoch 45/1000
#    - Generator Train Loss: 0.8014 - Generator Validation Loss: 0.8822
# No improvement for 4 epoch(s).
# Epoch 46/1000
#    - Generator Train Loss: 0.8061 - Generator Validation Loss: 0.8836
# No improvement for 5 epoch(s).
# Epoch 47/1000
#    - Generator Train Loss: 0.8043 - Generator Validation Loss: 0.8731
# No improvement for 6 epoch(s).
# Epoch 48/1000
#    - Generator Train Loss: 0.7996 - Generator Validation Loss: 0.9000
# No improvement for 7 epoch(s).
# Epoch 49/1000
#    - Generator Train Loss: 0.8021 - Generator Validation Loss: 0.8709
# No improvement for 8 epoch(s).
# Epoch 50/1000
#    - Generator Train Loss: 0.7985 - Generator Validation Loss: 0.8720
# No improvement for 9 epoch(s).
# Epoch 51/1000
#    - Generator Train Loss: 0.7992 - Generator Validation Loss: 0.9160
# Validation loss improved. Best model updated.
# Epoch 52/1000
#    - Generator Train Loss: 0.8000 - Generator Validation Loss: 0.8673
# Validation loss improved. Best model updated.
# Epoch 53/1000
#    - Generator Train Loss: 0.7970 - Generator Validation Loss: 0.8508
# Validation loss improved. Best model updated.
# Epoch 54/1000
#    - Generator Train Loss: 0.7993 - Generator Validation Loss: 0.8943
# No improvement for 1 epoch(s).
# Epoch 55/1000
#    - Generator Train Loss: 0.7960 - Generator Validation Loss: 0.8643
# No improvement for 2 epoch(s).
# Epoch 56/1000
#    - Generator Train Loss: 0.7922 - Generator Validation Loss: 0.8555
# No improvement for 3 epoch(s).
# Epoch 57/1000
#    - Generator Train Loss: 0.7939 - Generator Validation Loss: 0.8455
# Validation loss improved. Best model updated.
# Epoch 58/1000
#    - Generator Train Loss: 0.7957 - Generator Validation Loss: 0.8626
# No improvement for 1 epoch(s).
# Epoch 59/1000
#    - Generator Train Loss: 0.7955 - Generator Validation Loss: 0.8511
# No improvement for 2 epoch(s).
# Epoch 60/1000
#    - Generator Train Loss: 0.7962 - Generator Validation Loss: 0.8467
# No improvement for 3 epoch(s).
# Epoch 61/1000
#    - Generator Train Loss: 0.7956 - Generator Validation Loss: 0.8957
# No improvement for 4 epoch(s).
# Epoch 62/1000
#    - Generator Train Loss: 0.7949 - Generator Validation Loss: 0.8629
# No improvement for 5 epoch(s).
# Epoch 63/1000
#    - Generator Train Loss: 0.7991 - Generator Validation Loss: 0.8484
# No improvement for 6 epoch(s).
# Epoch 64/1000
#    - Generator Train Loss: 0.7926 - Generator Validation Loss: 0.8612
# No improvement for 7 epoch(s).
# Epoch 65/1000
#    - Generator Train Loss: 0.7965 - Generator Validation Loss: 0.8598
# No improvement for 8 epoch(s).
# Epoch 66/1000
#    - Generator Train Loss: 0.7953 - Generator Validation Loss: 0.8462
# No improvement for 9 epoch(s).
# Epoch 67/1000
#    - Generator Train Loss: 0.7916 - Generator Validation Loss: 0.8391
# Validation loss improved. Best model updated.
# Epoch 68/1000
#    - Generator Train Loss: 0.7957 - Generator Validation Loss: 0.8640
# No improvement for 1 epoch(s).
# Epoch 69/1000
#    - Generator Train Loss: 0.7957 - Generator Validation Loss: 0.8819
# No improvement for 2 epoch(s).
# Epoch 70/1000
#    - Generator Train Loss: 0.7937 - Generator Validation Loss: 0.8729
# No improvement for 3 epoch(s).
# Epoch 71/1000
#    - Generator Train Loss: 0.7934 - Generator Validation Loss: 0.8992
# No improvement for 4 epoch(s).
# Epoch 72/1000
#    - Generator Train Loss: 0.7928 - Generator Validation Loss: 0.8467
# No improvement for 5 epoch(s).
# Epoch 73/1000
#    - Generator Train Loss: 0.7905 - Generator Validation Loss: 0.8786
# No improvement for 6 epoch(s).
# Epoch 74/1000
#    - Generator Train Loss: 0.7908 - Generator Validation Loss: 0.8489
# No improvement for 7 epoch(s).
# Epoch 75/1000
#    - Generator Train Loss: 0.7932 - Generator Validation Loss: 0.8327
# Validation loss improved. Best model updated.
# Epoch 76/1000
#    - Generator Train Loss: 0.7916 - Generator Validation Loss: 0.8445
# No improvement for 1 epoch(s).
# Epoch 77/1000
#    - Generator Train Loss: 0.7927 - Generator Validation Loss: 0.8449
# No improvement for 2 epoch(s).
# Epoch 78/1000
#    - Generator Train Loss: 0.7905 - Generator Validation Loss: 0.8802
# No improvement for 3 epoch(s).
# Epoch 79/1000
#    - Generator Train Loss: 0.7898 - Generator Validation Loss: 0.8650
# No improvement for 4 epoch(s).
# Epoch 80/1000
#    - Generator Train Loss: 0.7870 - Generator Validation Loss: 0.8427
# No improvement for 5 epoch(s).
# Epoch 81/1000
#    - Generator Train Loss: 0.7875 - Generator Validation Loss: 0.8571
# No improvement for 6 epoch(s).
# Epoch 82/1000
#    - Generator Train Loss: 0.7924 - Generator Validation Loss: 0.8530
# No improvement for 7 epoch(s).
# Epoch 83/1000
#    - Generator Train Loss: 0.7896 - Generator Validation Loss: 0.8428
# No improvement for 8 epoch(s).
# Epoch 84/1000
#    - Generator Train Loss: 0.7819 - Generator Validation Loss: 0.8344
# No improvement for 9 epoch(s).
# Epoch 85/1000
#    - Generator Train Loss: 0.7895 - Generator Validation Loss: 0.8483
# No improvement for 10 epoch(s).
# Epoch 86/1000
#    - Generator Train Loss: 0.7916 - Generator Validation Loss: 0.8423
# No improvement for 11 epoch(s).
# Epoch 87/1000
#    - Generator Train Loss: 0.7877 - Generator Validation Loss: 0.8629
# No improvement for 12 epoch(s).
# Epoch 88/1000
#    - Generator Train Loss: 0.7897 - Generator Validation Loss: 0.8622
# No improvement for 13 epoch(s).
# Epoch 89/1000
#    - Generator Train Loss: 0.7890 - Generator Validation Loss: 0.8554
# No improvement for 14 epoch(s).
# Epoch 90/1000
#    - Generator Train Loss: 0.7855 - Generator Validation Loss: 0.8608
# No improvement for 15 epoch(s).
# Epoch 91/1000
#    - Generator Train Loss: 0.7873 - Generator Validation Loss: 0.8531
# No improvement for 16 epoch(s).
# Epoch 92/1000
#    - Generator Train Loss: 0.7888 - Generator Validation Loss: 0.8421
# No improvement for 17 epoch(s).
# Epoch 93/1000
#    - Generator Train Loss: 0.7902 - Generator Validation Loss: 0.8274
# Validation loss improved. Best model updated.
# Epoch 94/1000
#    - Generator Train Loss: 0.7877 - Generator Validation Loss: 0.8492
# No improvement for 1 epoch(s).
# Epoch 95/1000
#    - Generator Train Loss: 0.7875 - Generator Validation Loss: 0.8484
# No improvement for 2 epoch(s).
# Epoch 96/1000
#    - Generator Train Loss: 0.7863 - Generator Validation Loss: 0.8495
# No improvement for 3 epoch(s).
# Epoch 97/1000
#    - Generator Train Loss: 0.7857 - Generator Validation Loss: 0.8638
# No improvement for 4 epoch(s).
# Epoch 98/1000
#    - Generator Train Loss: 0.7901 - Generator Validation Loss: 0.8380
# No improvement for 5 epoch(s).
# Epoch 99/1000
#    - Generator Train Loss: 0.7848 - Generator Validation Loss: 0.8606
# No improvement for 6 epoch(s).
# Epoch 100/1000
#    - Generator Train Loss: 0.7885 - Generator Validation Loss: 0.8724
# No improvement for 7 epoch(s).
# Epoch 101/1000
#    - Generator Train Loss: 0.7931 - Generator Validation Loss: 0.8546
# No improvement for 8 epoch(s).
# Epoch 102/1000
#    - Generator Train Loss: 0.7880 - Generator Validation Loss: 0.8285
# No improvement for 9 epoch(s).
# Epoch 103/1000
#    - Generator Train Loss: 0.7899 - Generator Validation Loss: 0.8339
# No improvement for 10 epoch(s).
# Epoch 104/1000
#    - Generator Train Loss: 0.7782 - Generator Validation Loss: 0.8335
# No improvement for 11 epoch(s).
# Epoch 105/1000
#    - Generator Train Loss: 0.7849 - Generator Validation Loss: 0.8476
# No improvement for 12 epoch(s).
# Epoch 106/1000
#    - Generator Train Loss: 0.7861 - Generator Validation Loss: 0.8614
# No improvement for 13 epoch(s).
# Epoch 107/1000
#    - Generator Train Loss: 0.7808 - Generator Validation Loss: 0.8759
# No improvement for 14 epoch(s).
# Epoch 108/1000
#    - Generator Train Loss: 0.7856 - Generator Validation Loss: 0.8572
# No improvement for 15 epoch(s).
# Epoch 109/1000
#    - Generator Train Loss: 0.7861 - Generator Validation Loss: 0.8433
# No improvement for 16 epoch(s).
# Epoch 110/1000
#    - Generator Train Loss: 0.7842 - Generator Validation Loss: 0.8664
# No improvement for 17 epoch(s).
# Epoch 111/1000
#    - Generator Train Loss: 0.7829 - Generator Validation Loss: 0.8468
# No improvement for 18 epoch(s).
# Epoch 112/1000
#    - Generator Train Loss: 0.7792 - Generator Validation Loss: 0.8831
# No improvement for 19 epoch(s).
# Epoch 113/1000
#    - Generator Train Loss: 0.7836 - Generator Validation Loss: 0.8659
# No improvement for 20 epoch(s).
# Epoch 114/1000
#    - Generator Train Loss: 0.7832 - Generator Validation Loss: 0.8498
# No improvement for 21 epoch(s).
# Epoch 115/1000
#    - Generator Train Loss: 0.7891 - Generator Validation Loss: 0.8555
# No improvement for 22 epoch(s).
# Epoch 116/1000
#    - Generator Train Loss: 0.7816 - Generator Validation Loss: 0.8481
# No improvement for 23 epoch(s).
# Epoch 117/1000
#    - Generator Train Loss: 0.7829 - Generator Validation Loss: 0.8460
# No improvement for 24 epoch(s).
# Epoch 118/1000
#    - Generator Train Loss: 0.7854 - Generator Validation Loss: 0.8497
# No improvement for 25 epoch(s).
# Epoch 119/1000
#    - Generator Train Loss: 0.7840 - Generator Validation Loss: 0.8481
# No improvement for 26 epoch(s).
# Epoch 120/1000
#    - Generator Train Loss: 0.7872 - Generator Validation Loss: 0.8657
# No improvement for 27 epoch(s).
# Epoch 121/1000
#    - Generator Train Loss: 0.7861 - Generator Validation Loss: 0.8731
# No improvement for 28 epoch(s).
# Epoch 122/1000
#    - Generator Train Loss: 0.7864 - Generator Validation Loss: 0.8452
# No improvement for 29 epoch(s).
# Epoch 123/1000
#    - Generator Train Loss: 0.7779 - Generator Validation Loss: 0.8332
# No improvement for 30 epoch(s).
# Epoch 124/1000
#    - Generator Train Loss: 0.7788 - Generator Validation Loss: 0.8363
# No improvement for 31 epoch(s).
# Epoch 125/1000
#    - Generator Train Loss: 0.7803 - Generator Validation Loss: 0.8404
# No improvement for 32 epoch(s).
# Epoch 126/1000
#    - Generator Train Loss: 0.7822 - Generator Validation Loss: 0.8618
# No improvement for 33 epoch(s).
# Epoch 127/1000
#    - Generator Train Loss: 0.7852 - Generator Validation Loss: 0.8385
# No improvement for 34 epoch(s).
# Epoch 128/1000
#    - Generator Train Loss: 0.7818 - Generator Validation Loss: 0.8536
# No improvement for 35 epoch(s).
# Epoch 129/1000
#    - Generator Train Loss: 0.7807 - Generator Validation Loss: 0.8699
# No improvement for 36 epoch(s).
# Epoch 130/1000
#    - Generator Train Loss: 0.7836 - Generator Validation Loss: 0.8505
# No improvement for 37 epoch(s).
# Epoch 131/1000
#    - Generator Train Loss: 0.7803 - Generator Validation Loss: 0.8528
# No improvement for 38 epoch(s).
# Epoch 132/1000
#    - Generator Train Loss: 0.7767 - Generator Validation Loss: 0.8838
# No improvement for 39 epoch(s).
# Epoch 133/1000
#    - Generator Train Loss: 0.7801 - Generator Validation Loss: 0.8548
# No improvement for 40 epoch(s).
# Epoch 134/1000
#    - Generator Train Loss: 0.7832 - Generator Validation Loss: 0.8563
# No improvement for 41 epoch(s).
# Epoch 135/1000
#    - Generator Train Loss: 0.7831 - Generator Validation Loss: 0.8468
# No improvement for 42 epoch(s).
# Epoch 136/1000
#    - Generator Train Loss: 0.7826 - Generator Validation Loss: 0.8641
# No improvement for 43 epoch(s).
# Epoch 137/1000
#    - Generator Train Loss: 0.7818 - Generator Validation Loss: 0.8586
# No improvement for 44 epoch(s).
# Epoch 138/1000
#    - Generator Train Loss: 0.7842 - Generator Validation Loss: 0.8462
# No improvement for 45 epoch(s).
# Epoch 139/1000
#    - Generator Train Loss: 0.7848 - Generator Validation Loss: 0.8430
# No improvement for 46 epoch(s).
# Epoch 140/1000
#    - Generator Train Loss: 0.7813 - Generator Validation Loss: 0.8499
# No improvement for 47 epoch(s).
# Epoch 141/1000
#    - Generator Train Loss: 0.7855 - Generator Validation Loss: 0.8442
# No improvement for 48 epoch(s).
# Epoch 142/1000
#    - Generator Train Loss: 0.7817 - Generator Validation Loss: 0.8535
# No improvement for 49 epoch(s).
# Epoch 143/1000
#    - Generator Train Loss: 0.7828 - Generator Validation Loss: 0.8391
# No improvement for 50 epoch(s).
# Epoch 144/1000
#    - Generator Train Loss: 0.7812 - Generator Validation Loss: 0.8436
# No improvement for 51 epoch(s).
# Epoch 145/1000
#    - Generator Train Loss: 0.7809 - Generator Validation Loss: 0.8414
# No improvement for 52 epoch(s).
# Epoch 146/1000
#    - Generator Train Loss: 0.7779 - Generator Validation Loss: 0.8524
# No improvement for 53 epoch(s).
# Epoch 147/1000
#    - Generator Train Loss: 0.7797 - Generator Validation Loss: 0.8460
# No improvement for 54 epoch(s).
# Epoch 148/1000
#    - Generator Train Loss: 0.7784 - Generator Validation Loss: 0.8515
# No improvement for 55 epoch(s).
# Epoch 149/1000
#    - Generator Train Loss: 0.7833 - Generator Validation Loss: 0.8749
# No improvement for 56 epoch(s).
# Epoch 150/1000
#    - Generator Train Loss: 0.7822 - Generator Validation Loss: 0.8455
# No improvement for 57 epoch(s).
# Epoch 151/1000
#    - Generator Train Loss: 0.7801 - Generator Validation Loss: 0.8523
# No improvement for 58 epoch(s).
# Epoch 152/1000
#    - Generator Train Loss: 0.7780 - Generator Validation Loss: 0.8518
# No improvement for 59 epoch(s).
# Epoch 153/1000
#    - Generator Train Loss: 0.7761 - Generator Validation Loss: 0.8443
# No improvement for 60 epoch(s).
# Epoch 154/1000
#    - Generator Train Loss: 0.7811 - Generator Validation Loss: 0.8477
# No improvement for 61 epoch(s).
# Epoch 155/1000
#    - Generator Train Loss: 0.7793 - Generator Validation Loss: 0.8422
# No improvement for 62 epoch(s).
# Epoch 156/1000
#    - Generator Train Loss: 0.7796 - Generator Validation Loss: 0.8503
# No improvement for 63 epoch(s).
# Epoch 157/1000
#    - Generator Train Loss: 0.7776 - Generator Validation Loss: 0.8561
# No improvement for 64 epoch(s).
# Epoch 158/1000
#    - Generator Train Loss: 0.7811 - Generator Validation Loss: 0.8406
# No improvement for 65 epoch(s).
# Epoch 159/1000
#    - Generator Train Loss: 0.7792 - Generator Validation Loss: 0.8543
# No improvement for 66 epoch(s).
# Epoch 160/1000
#    - Generator Train Loss: 0.7806 - Generator Validation Loss: 0.8455
# No improvement for 67 epoch(s).
# Epoch 161/1000
#    - Generator Train Loss: 0.7848 - Generator Validation Loss: 0.8408
# No improvement for 68 epoch(s).
# Epoch 162/1000
#    - Generator Train Loss: 0.7795 - Generator Validation Loss: 0.8412
# No improvement for 69 epoch(s).
# Epoch 163/1000
#    - Generator Train Loss: 0.7780 - Generator Validation Loss: 0.8484
# No improvement for 70 epoch(s).
# Epoch 164/1000
#    - Generator Train Loss: 0.7800 - Generator Validation Loss: 0.8456
# No improvement for 71 epoch(s).
# Epoch 165/1000
#    - Generator Train Loss: 0.7806 - Generator Validation Loss: 0.8489
# No improvement for 72 epoch(s).
# Epoch 166/1000
#    - Generator Train Loss: 0.7770 - Generator Validation Loss: 0.8474
# No improvement for 73 epoch(s).
# Epoch 167/1000
#    - Generator Train Loss: 0.7784 - Generator Validation Loss: 0.8552
# No improvement for 74 epoch(s).
# Epoch 168/1000
#    - Generator Train Loss: 0.7774 - Generator Validation Loss: 0.8463
# No improvement for 75 epoch(s).
# Epoch 169/1000
#    - Generator Train Loss: 0.7759 - Generator Validation Loss: 0.8357
# No improvement for 76 epoch(s).
# Epoch 170/1000
#    - Generator Train Loss: 0.7794 - Generator Validation Loss: 0.8449
# No improvement for 77 epoch(s).
# Epoch 171/1000
#    - Generator Train Loss: 0.7775 - Generator Validation Loss: 0.8531
# No improvement for 78 epoch(s).
# Epoch 172/1000
#    - Generator Train Loss: 0.7812 - Generator Validation Loss: 0.8346
# No improvement for 79 epoch(s).
# Epoch 173/1000
#    - Generator Train Loss: 0.7749 - Generator Validation Loss: 0.8372
# No improvement for 80 epoch(s).
# Epoch 174/1000
#    - Generator Train Loss: 0.7735 - Generator Validation Loss: 0.8504
# No improvement for 81 epoch(s).
# Epoch 175/1000
#    - Generator Train Loss: 0.7770 - Generator Validation Loss: 0.8444
# No improvement for 82 epoch(s).
# Epoch 176/1000
#    - Generator Train Loss: 0.7768 - Generator Validation Loss: 0.8457
# No improvement for 83 epoch(s).
# Epoch 177/1000
#    - Generator Train Loss: 0.7819 - Generator Validation Loss: 0.8486
# No improvement for 84 epoch(s).
# Epoch 178/1000
#    - Generator Train Loss: 0.7780 - Generator Validation Loss: 0.8565
# No improvement for 85 epoch(s).
# Epoch 179/1000
#    - Generator Train Loss: 0.7757 - Generator Validation Loss: 0.8626
# No improvement for 86 epoch(s).
# Epoch 180/1000
#    - Generator Train Loss: 0.7734 - Generator Validation Loss: 0.8869
# No improvement for 87 epoch(s).
# Epoch 181/1000
#    - Generator Train Loss: 0.7781 - Generator Validation Loss: 0.8518
# No improvement for 88 epoch(s).
# Epoch 182/1000
#    - Generator Train Loss: 0.7765 - Generator Validation Loss: 0.8500
# No improvement for 89 epoch(s).
# Epoch 183/1000
#    - Generator Train Loss: 0.7724 - Generator Validation Loss: 0.8501
# No improvement for 90 epoch(s).
# Epoch 184/1000
#    - Generator Train Loss: 0.7762 - Generator Validation Loss: 0.9247
# No improvement for 91 epoch(s).
# Epoch 185/1000
#    - Generator Train Loss: 0.7795 - Generator Validation Loss: 0.8445
# No improvement for 92 epoch(s).
# Epoch 186/1000
#    - Generator Train Loss: 0.7772 - Generator Validation Loss: 0.8588
# No improvement for 93 epoch(s).
# Epoch 187/1000
#    - Generator Train Loss: 0.7766 - Generator Validation Loss: 0.8470
# No improvement for 94 epoch(s).
# Epoch 188/1000
#    - Generator Train Loss: 0.7764 - Generator Validation Loss: 0.8438
# No improvement for 95 epoch(s).
# Epoch 189/1000
#    - Generator Train Loss: 0.7767 - Generator Validation Loss: 0.8457
# No improvement for 96 epoch(s).
# Epoch 190/1000
#    - Generator Train Loss: 0.7697 - Generator Validation Loss: 0.8521
# No improvement for 97 epoch(s).
# Epoch 191/1000
#    - Generator Train Loss: 0.7785 - Generator Validation Loss: 0.8413
# No improvement for 98 epoch(s).
# Epoch 192/1000
#    - Generator Train Loss: 0.7746 - Generator Validation Loss: 0.8582
# No improvement for 99 epoch(s).
# Epoch 193/1000
#    - Generator Train Loss: 0.7749 - Generator Validation Loss: 0.8502
# No improvement for 100 epoch(s).
# Early stopping triggered!

# %%
# save the best model
os.makedirs('./gen_models/models', exist_ok=True)
if gen_best_model_state is not None:
    torch.save(gen_best_model_state, gen_best_model_filename)
    print(f"Best model saved to {gen_best_model_filename}")
# Out:
# Best model saved to ./gen_models/best_model_0.8274214518697638_20250427_160049.pth

# %% [markdown]
# # Model Testing

# %%
generator.load_state_dict(torch.load(gen_best_model_filename, map_location=device, weights_only=True))
generator.eval()

# Arrays to store all predictions and all ground truth masks
pred_mask_all, target_all = [], []

with torch.no_grad():
    for batch in test_loader:
        images, target = batch
        images = images.to(device)
        target = target.to(device)

        # Make test predictions
        pred_mask = generator(images)

        pred_mask_all.append(pred_mask.cpu().numpy())
        target_all.append(target.cpu().numpy())

    # Concatenate all batches into a single array for performance                        
    preds = np.concatenate(pred_mask_all, axis=0)   
    trues = np.concatenate(target_all, axis=0)        

    # Squeeze from 4 dimensions into 3 since we use only one channel
    if preds.ndim == 4 and preds.shape[1] == 1:
        preds = preds.squeeze(1)
        trues = trues.squeeze(1)

    # Binarize predictions
    preds  = (preds > 0.5).astype(np.uint8)
    trues  = trues.astype(np.uint8)

    preds = preds.flatten()
    trues = trues.flatten()

    # Calculate TP, FP, FN for evaluation metrics
    tp = np.logical_and(preds==1, trues==1).sum()
    fp = np.logical_and(preds==1, trues==0).sum()
    fn = np.logical_and(preds==0, trues==1).sum()

    # Calculate evaluation metrics
    smooth = 1e-6
    dice = (2*tp + smooth) / (2*tp + fp + fn + smooth)
    iou  = (tp + smooth)   / (tp + fp + fn + smooth)
    recall = tp / (tp + fn + smooth)

                             
    # Dice coefficient
    # IoU (Jaccard Index)
    # Recall - We care a lot about false negatives
    metrics = {
        'Dice Coefficient': dice,
        'IoU': iou,
        'Recall': recall
        }
    
    print("\n **Test Results:**")
    for key, value in metrics.items():
        print(f"{key}: {value:.4f}")
# Out:
#  **Test Results:**
# Dice Coefficient: 0.2614
# IoU: 0.1503
# Recall: 0.6405

# %%
preds.shape
# Out:
# (1729536,)

# %%
img, lab = next(iter(test_loader))
pred = generator(img.to(device))
tensor_np = pred[5][0].detach().cpu().numpy()

plt.imshow(tensor_np, cmap='gray')
plt.colorbar()
plt.show()

# %%
tensor_np = lab[5][0].detach().cpu().numpy()

plt.imshow(tensor_np, cmap='gray')
plt.colorbar()
plt.show()
